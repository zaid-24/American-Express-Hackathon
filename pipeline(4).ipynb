# %% [markdown]
# ## Training and Testing Pipeline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
train_data = pd.read_csv('dataset/train_data.csv')
test_data = pd.read_csv('dataset/test_data.csv')

# %%
# Display options
pd.set_option('display.max_columns',50)

# %%
train_data.shape
train_data.head(2)
# Out:
# (948, 23)
#    match id team1  team1_id  \
# 0   9331181    Ba     11283
# 1   8797060    Ed        20
#
#                                     team1_roster_ids  team2  team2_id  \
# 0  9373356.0:7857520.0:4232164.0:4566540.0:329940...  Hl Ph     12634
# 1  2089079.0:6139370.0:2076192.0:62432.0:2083409....  Wt Is        41
#
#                                     team2_roster_ids winner  winner_id  \
# 0  3500958.0:4231751.0:2735081.0:2035102.0:369833...  Hl Ph      12634
# 1  4690258.0:4069666.0:4230127.0:1942317.0:161392...     Ed         20
#
#   toss winner toss decision        venue        city    match_dt  \
# 0       Hl Ph         field  Hr Ct Sm Ie      Indore  2022-10-20
# 1       Wt Is         field  Kn Ol Bn Bs  Bridgetown  2022-01-23
#
#           lighting     series_name   season  ground_id  \
# 0  day/night match     Sd Mq Ai Ty  2022/23       7398
# 1  day/night match  Ed tr of Wt Is  2021/22       1406
#
#    team_count_50runs_last15  team_winp_last5  team1only_avg_runs_last15  \
# 0                  1.666667         0.672131                      139.0
# 1                  1.285714         1.952381                      156.0
#
#    team1_winp_team2_last15  ground_avg_runs_last15
# 0                    100.0              157.178571
# 1                     50.0              103.500000

# %%
test_data.shape
test_data.head(2)
# Out:
# (271, 21)
#    match id     team1  team1_id  \
# 0   9250275        Jy     28594
# 1   9262189  Ga An Ws     36084
#
#                                     team1_roster_ids        team2  team2_id  \
# 0  7438955.0:8271969.0:8369661.0:3685247.0:259025...  Ud Ss of Aa        90
# 1  3715690.0:6818622.0:4069666.0:393014.0:4690188...        Ja Ts     36098
#
#                                     team2_roster_ids  toss winner  \
# 0  2436944.0:8117500.0:6703528.0:3010748.0:161387...  Ud Ss of Aa
# 1  4690258.0:3761246.0:8464385.0:5742470.0:315072...        Ja Ts
#
#   toss decision     venue        city  match_dt     lighting  \
# 0         field  Bo Ac Cb    Bulawayo  11-07-22    day match
# 1         field  Pe Sm Ga  Providence  21-09-22  night match
#
#             series_name season  ground_id  team_count_50runs_last15  \
# 0  Ud Ss of Aa tr of Ze   2022       3226                  0.000000
# 1              Cn Pr Le   2022      13915                  0.615385
#
#    team_winp_last5  team1only_avg_runs_last15  team1_winp_team2_last15  \
# 0         0.019608                        NaN                     0.00
# 1         0.344262                 151.285714                    66.67
#
#    ground_avg_runs_last15
# 0                     NaN
# 1                   153.5

# %% [markdown]
# # Calculating batsmen features

# %%
batsmen=pd.read_csv('dataset/batsman_level_scorecard.csv')

# %%
batsmen.head(2)
# Out:
#    match id batsman  batsman_id                           batsman_details  \
# 0   8638034   KD Ce   7907451.0  NZ:Right-hand bat:Right-arm medium-fast:
# 1   8638034   TL St   4381761.0                   NZ:Right-hand bat:None:
#
#    is_batsman_captain  is_batsman_keeper  inning  runs  balls_faced  \
# 0                 0.0                0.0       1     7            5
# 1                 0.0                1.0       1    46           46
#
#    over_faced_first wicket kind out_by_bowler out_by_fielder  bowler_id  \
# 0               1.1      caught         JS Nm          TM Jn  2486896.0
# 1               1.2      caught          R Ra          MG Bl  6718382.0
#
#                              bowler_details  is_bowler_keeper  \
# 0   NZ:Left-hand bat:Right-arm medium-fast:               0.0
# 1  NZ:Left-hand bat:Slow left-arm orthodox:               0.0
#
#    is_bowler_captain  strike_rate  Fours  Sixes    match_dt
# 0                0.0        140.0    1.0    NaN  2021-01-01
# 1                0.0        100.0    4.0    1.0  2021-01-01

# %%
# calculating 2 dictionaries to store {batsman_id: batsman average } and {batsman_id: batsman strike rate}

total_runs = {}  
balls_faced = {}
matches_played = {}

for i in range(len(batsmen)):
    batsman_id = batsmen['batsman_id'][i]
    runs = batsmen['runs'][i]
    balls = batsmen['balls_faced'][i]
    match_id = batsmen['match id'][i]
    if batsman_id in total_runs:
        total_runs[batsman_id] += runs
        balls_faced[batsman_id] += balls
        matches_played[batsman_id] += 1
    else:
        total_runs[batsman_id] = runs
        balls_faced[batsman_id] = balls
        matches_played[batsman_id] = 1
        
batsman_avg = {}
batsman_sr = {}

for batsman_id in total_runs:
    batsman_avg[batsman_id] = total_runs[batsman_id] / matches_played[batsman_id]
    batsman_sr[batsman_id] = total_runs[batsman_id] / balls_faced[batsman_id] * 100

# %% [markdown]
# # Bowler level features

# %%
bowlers=pd.read_csv('dataset/bowler_level_scorecard.csv')

# %%
bowlers.head()
# Out:
#    match id    bowler  bowler_id                             bowler_details  \
# 0   8638034     BV Ss  6718396.0   NZ:Right-hand bat:Right-arm medium-fast:
# 1   8638034     HK Bt  1585464.0    NZ:Left-hand bat:Right-arm medium-fast:
# 2   8638034     JS Nm  2486896.0    NZ:Left-hand bat:Right-arm medium-fast:
# 3   8638034  LV vn Bk  3083667.0  NED:Right-hand bat:Right-arm medium-fast:
# 4   8638034     PF Yd  4950294.0         NZ:Right-hand bat:Legbreak googly:
#
#    is_bowler_captain  is_bowler_keeper  inning  runs  wicket_count  \
# 0                0.0               0.0       1    21             0
# 1                0.0               0.0       1    34             1
# 2                0.0               0.0       1    23             2
# 3                0.0               0.0       1    31             1
# 4                0.0               0.0       1    21             1
#
#    balls_bowled  economy  maiden  dots  Fours  Sixes  wides  noballs  \
# 0            12    10.50       0   3.0      1      1      3        1
# 1            24     8.50       0   7.0      3      1      2        0
# 2            24     5.75       0  12.0      1      1      0        0
# 3            24     7.75       0   9.0      4      0      2        0
# 4            24     5.25       0   8.0      0      0      1        0
#
#      match_dt
# 0  2021-01-01
# 1  2021-01-01
# 2  2021-01-01
# 3  2021-01-01
# 4  2021-01-01

# %%
# calculating 2 dictionaries to store {bowler_id: bowler strike rate } , {bowler_id: bowler economy} , {bowler_id: bowler extras rate}

total_matches = {}
total_wickets = {}
total_ball_bowled = {}
total_extras = {}
total_economy = {}

for i in range(len(bowlers)):
    bowler_id = bowlers['bowler_id'][i]
    wickets = bowlers['wicket_count'][i]
    balls = bowlers['balls_bowled'][i]
    runs = bowlers['runs'][i]
    extras = bowlers['wides'][i] + bowlers['noballs'][i]
    match_id = bowlers['match id'][i]
    economy=bowlers['economy'][i]
    if bowler_id in total_matches:
        total_matches[bowler_id] += 1
        total_wickets[bowler_id] += wickets
        total_ball_bowled[bowler_id] += balls
        total_extras[bowler_id] += extras
        total_economy[bowler_id] += economy
    else:
        total_matches[bowler_id] = 1
        total_wickets[bowler_id] = wickets
        total_ball_bowled[bowler_id] = balls
        total_extras[bowler_id] = extras
        total_economy[bowler_id] = economy
        
bowler_sr = {}
bowler_economy = {}
bowler_extras = {}

for bowler_id in total_matches:
    bowler_economy[bowler_id] = total_economy[bowler_id] / total_matches[bowler_id]
    bowler_extras[bowler_id] = total_extras[bowler_id] / total_ball_bowled[bowler_id]
    if total_wickets[bowler_id] == 0:
        bowler_sr[bowler_id] = 0
    else:
        bowler_sr[bowler_id] = total_ball_bowled[bowler_id] /total_wickets[bowler_id]

# %% [markdown]
# ## Match level features

# %%
match=pd.read_csv('dataset/match_level_scorecard.csv')

# %%
match.head()
# Out:
#    match id  team1  team2 winner       by  win amount toss winner  \
# 0   8638034  Nn Ds     Wn     Wn  wickets         9.0          Wn
# 1   8588005  Me Rs  Sy Tr  Sy Tr     runs         7.0       Sy Tr
# 2   8587837  Sy Ss  Be Ht  Be Ht  wickets         4.0       Sy Ss
# 3   8638041  Nn Ds     Oo     Oo  wickets         2.0          Oo
# 4   8587921  Ht Hs  Me Ss  Ht Hs     runs        21.0       Me Ss
#
#   toss decision     venue             city    match_dt         lighting  \
# 0         field     By Ol  Mount Maunganui  2021-01-01      night match
# 1         field     Ca Ol          Carrara  2021-01-01      night match
# 2           bat  Be Ct Gd         Brisbane  2021-01-02      night match
# 3         field     By Ol  Mount Maunganui  2021-01-02      night match
# 4         field     Be Ol           Hobart  2021-01-02  day/night match
#
#   series_name   season  ground_id umpire1 umpire2  inning1_runs  \
# 0       Sr Sh  2020/21      17681   Dn Mw   TJ Pe           148
# 1    Bg Bh Le  2020/21       6663    D Tr   PJ Ge           166
# 2    Bg Bh Le  2020/21       1476   GJ Dn   PJ Ge           165
# 3       Sr Sh  2020/21      17681   GA St   TJ Pe           153
# 4    Bg Bh Le  2020/21       6348   GA Ad   NR Je           164
#
#    inning1_wickets  inning1_balls  inning2_runs  inning2_wickets  \
# 0                6            130         152.0              1.0
# 1                6            106         117.0              2.0
# 2                8            126         171.0              6.0
# 3                7            128         156.0              8.0
# 4                5            126         143.0              9.0
#
#    inning2_balls  team1_id                                   team1_roster_ids  \
# 0           97.0     17982  7907451.0:4381761.0:31464.0:258649.0:4949790.0...
# 1           74.0     33942  37351.0:46794.0:5406540.0:2231928.0:181404.0:1...
# 2          119.0     33956  7869987.0:7620283.0:2076192.0:4002340.0:306369...
# 3          126.0     17982  7907451.0:4381761.0:31464.0:4949790.0:258649.0...
# 4          123.0     33928  4223883.0:2161599.0:1655436.0:5788418.0:319948...
#
#    team2_id                                   team2_roster_ids  \
# 0     18570  2653993.0:6718326.0:6718382.0:2486896.0:228878...
# 1     33963  1506098.0:1749075.0:36665.0:2083409.0:7534652....
# 2     33921  7620269.0:2286437.0:87191.0:5786766.0:3114803....
# 3     18360  2319638.0:256080.0:7918280.0:3913447.0:2690498...
# 4     33949  363047.0:2275097.0:3901078.0:2275195.0:4230127...
#
#       series_type  winner_id  player_of_the_match_id
# 0  other_domestic      18570                     NaN
# 1  other_domestic      33963               1749075.0
# 2  other_domestic      33921               3890984.0
# 3  other_domestic      18360                     NaN
# 4  other_domestic      33928               3125849.0

# %%
# # calculating 2 dictionaries to store {team_id: team average }
#  if team1 has won toss and choose bat then inning1 score will be team1 score and inning2 score will be team2 score

total_runs = {}
total_matches={}
for i in range(len(match)):
    
    toss_winner = match['toss winner'][i]
    team2=toss_winner
    
    if toss_winner == match['team2_id'][i]:
        team1 = match['team1_id'][i]
    else:
        team1 = match['team2_id'][i]
    
    if match['toss decision'][i] == 'bat':
        team2_score=match['inning1_runs'][i]
        team1_score=match['inning2_runs'][i]
    
    else:
        team1_score=match['inning1_runs'][i]
        team2_score=match['inning2_runs'][i]
    
    if team1 in total_runs:
        total_runs[team1] += team1_score
        total_matches[team1] += 1
    
    else:
        total_runs[team1] = team1_score
        total_matches[team1] = 1
        
    if team2 in total_runs:
        total_runs[team2] += team2_score
        total_matches[team2] += 1
    
    else:
        total_runs[team2] = team2_score
        total_matches[team2] = 1
        
team_avg = {}

for team_id in total_runs:
    team_avg[team_id] = total_runs[team_id] / total_matches[team_id]

# %%
def winpCrossLastn(team1_id, team2_id, date, n):
    '''
    Function to compute team1's win% against team2 from the current game in their past n encounters.
    
    Input-
    1. team1_id: ID of team1 to calculate win% of.
    2. team2_id: ID of team2 to calculate win% against.
    3: date: match date of the current game for which the feature is to be calculated.
    4. n: look-back window of games for both these teams.
    
    Output- None
    
    Returns- Float value denoting team1's win% against team2 in their past n games against each other.
    '''
    # filter out games where either team1_id is input team1 and team2_id is input team2, or where team2_id is input team1 and team1_id is input team2.
    # Also, match date is less than current games's input date, sort desc by date and get top n rows (games)
    df_rel = match[(match['match_dt']<date)&\
                      (((match['team1_id']==team1_id)&(match['team2_id']==team2_id))|((match['team1_id']==team2_id)&(match['team2_id']==team1_id)))]\
                        .sort_values(by='match_dt', ascending=False).head(n)
    win_count = df_rel[df_rel['winner_id']==team1_id].shape[0] # Counting number of rows (games) where winner is input team1.
    if win_count == 0:
        return 0
    return round(win_count*100/df_rel.shape[0], 2) # return Float denoting team1's win% against team2 in past n games rounded to 2 decimal places.

# %%
def win_percentage_last_n_matches(team_id, date,n):
    '''
    Function to calculate a team's win percentage in their last n games.

    '''
    # Filter games where team1 or team2 is the input team_id and the match date is before the input date
    df_rel = match[(match['match_dt'] < date) &
                            ((match['team1_id'] == team_id) | (match['team2_id'] == team_id))]\
                            .sort_values(by='match_dt', ascending=False).head(n)
    
    # Calculate the number of wins
    wins = df_rel[(df_rel['winner_id'] == team_id)].shape[0]
    
    # Calculate the number of matches
    total_matches = df_rel.shape[0]
    
    if total_matches == 0:
        return 0.0  # Avoid division by zero
    
    # Calculate win percentage
    win_percentage = (wins / total_matches) * 100
    return win_percentage

# %%
train_data.head(2)
# Out:
#    match id team1  team1_id  \
# 0   9331181    Ba     11283
# 1   8797060    Ed        20
#
#                                     team1_roster_ids  team2  team2_id  \
# 0  9373356.0:7857520.0:4232164.0:4566540.0:329940...  Hl Ph     12634
# 1  2089079.0:6139370.0:2076192.0:62432.0:2083409....  Wt Is        41
#
#                                     team2_roster_ids winner  winner_id  \
# 0  3500958.0:4231751.0:2735081.0:2035102.0:369833...  Hl Ph      12634
# 1  4690258.0:4069666.0:4230127.0:1942317.0:161392...     Ed         20
#
#   toss winner toss decision        venue        city    match_dt  \
# 0       Hl Ph         field  Hr Ct Sm Ie      Indore  2022-10-20
# 1       Wt Is         field  Kn Ol Bn Bs  Bridgetown  2022-01-23
#
#           lighting     series_name   season  ground_id  \
# 0  day/night match     Sd Mq Ai Ty  2022/23       7398
# 1  day/night match  Ed tr of Wt Is  2021/22       1406
#
#    team_count_50runs_last15  team_winp_last5  team1only_avg_runs_last15  \
# 0                  1.666667         0.672131                      139.0
# 1                  1.285714         1.952381                      156.0
#
#    team1_winp_team2_last15  ground_avg_runs_last15
# 0                    100.0              157.178571
# 1                     50.0              103.500000

# %%
test_data.head(2)
# Out:
#    match id     team1  team1_id  \
# 0   9250275        Jy     28594
# 1   9262189  Ga An Ws     36084
#
#                                     team1_roster_ids        team2  team2_id  \
# 0  7438955.0:8271969.0:8369661.0:3685247.0:259025...  Ud Ss of Aa        90
# 1  3715690.0:6818622.0:4069666.0:393014.0:4690188...        Ja Ts     36098
#
#                                     team2_roster_ids  toss winner  \
# 0  2436944.0:8117500.0:6703528.0:3010748.0:161387...  Ud Ss of Aa
# 1  4690258.0:3761246.0:8464385.0:5742470.0:315072...        Ja Ts
#
#   toss decision     venue        city  match_dt     lighting  \
# 0         field  Bo Ac Cb    Bulawayo  11-07-22    day match
# 1         field  Pe Sm Ga  Providence  21-09-22  night match
#
#             series_name season  ground_id  team_count_50runs_last15  \
# 0  Ud Ss of Aa tr of Ze   2022       3226                  0.000000
# 1              Cn Pr Le   2022      13915                  0.615385
#
#    team_winp_last5  team1only_avg_runs_last15  team1_winp_team2_last15  \
# 0         0.019608                        NaN                     0.00
# 1         0.344262                 151.285714                    66.67
#
#    ground_avg_runs_last15
# 0                     NaN
# 1                   153.5

# %% [markdown]
# # Combining the features of dataset

# %%
# from geopy.geocoders import Nominatim

# # Initialize Nominatim API
# geolocator = Nominatim(user_agent="my_geocoder")

# Creating new columns in train_data and initializing with 0
train_data['batsmens_averages_1'] = 0
train_data['batsmens_strike_rates_1'] = 0
train_data['bowlers_strike_rates_1'] = 0
train_data['bowlers_economy_1'] = 0
train_data['bowlers_extras_1'] = 0

train_data['batsmens_averages_2'] = 0
train_data['batsmens_strike_rates_2'] = 0
train_data['bowlers_strike_rates_2'] = 0
train_data['bowlers_economy_2'] = 0
train_data['bowlers_extras_2'] = 0

train_data['batsmens_averages_ratios'] = 0
train_data['batsmens_strike_rates_ratios'] = 0
train_data['bowlers_strike_rates_ratios'] = 0
train_data['bowlers_economy_ratios'] = 0
train_data['bowlers_extras_ratios'] = 0

train_data['team1_winp_team2_last10']=0
train_data['team1_average_score'] = 0
train_data['team2_average_score'] = 0
train_data['win_percentage_team1_last_15'] = 0
train_data['win_percentage_team2_last_15'] = 0


# train_data['location_humidity'] = 0
# train_data['location_temperature'] = 0

# Filling the values in the new columns
for i in range(len(train_data)):
    # Getting ids of batsmen and bowlers from team roster id separated by :
    team1_players_ids = train_data['team1_roster_ids'][i].split(':')
    team2_players_ids = train_data['team2_roster_ids'][i].split(':')
    # print(i,team1_players_ids,team2_players_ids)
    # For team1 check if id is present in the dictionary and add the values
    for player_id in team1_players_ids:
        player_id = int(float(player_id))
        if player_id in batsman_avg:
            train_data.at[i, 'batsmens_averages_1'] += batsman_avg[player_id]
            train_data.at[i, 'batsmens_strike_rates_1'] += batsman_sr[player_id]
        if player_id in bowler_sr:
            train_data.at[i, 'bowlers_strike_rates_1'] += bowler_sr[player_id]
            train_data.at[i, 'bowlers_economy_1'] += bowler_economy[player_id]
            train_data.at[i, 'bowlers_extras_1'] += bowler_extras[player_id]
            
    # For team2 check if id is present in the dictionary and add the values
    for player_id in team2_players_ids:
        player_id = int(float(player_id))
        if player_id in batsman_avg:
            train_data.at[i, 'batsmens_averages_2'] += batsman_avg[player_id]
            train_data.at[i, 'batsmens_strike_rates_2'] += batsman_sr[player_id]
        if player_id in bowler_sr:
            train_data.at[i, 'bowlers_strike_rates_2'] += bowler_sr[player_id]
            train_data.at[i, 'bowlers_economy_2'] += bowler_economy[player_id]
            train_data.at[i, 'bowlers_extras_2'] += bowler_extras[player_id]
    
    # filling ratios
    if train_data['batsmens_averages_2'][i] == 0:
        train_data['batsmens_averages_2'][i] = 1
        
    if train_data['batsmens_strike_rates_2'][i] == 0:
        train_data['batsmens_strike_rates_2'][i] = 1
    if train_data['bowlers_strike_rates_2'][i] == 0:
        train_data['bowlers_strike_rates_2'][i] = 1
        
    if train_data['bowlers_economy_2'][i] == 0:
        train_data['bowlers_economy_2'][i] = 1
        
    if train_data['bowlers_extras_2'][i] == 0:
        train_data['bowlers_extras_2'][i] = 1
        
    
    train_data.at[i, 'batsmens_averages_ratios'] = train_data['batsmens_averages_1'][i] / train_data['batsmens_averages_2'][i]
    train_data.at[i, 'batsmens_strike_rates_ratios'] = train_data['batsmens_strike_rates_1'][i] / train_data['batsmens_strike_rates_2'][i]
    train_data.at[i, 'bowlers_strike_rates_ratios'] = train_data['bowlers_strike_rates_1'][i] / train_data['bowlers_strike_rates_2'][i]
    train_data.at[i, 'bowlers_economy_ratios'] = train_data['bowlers_economy_1'][i] / train_data['bowlers_economy_2'][i]
    train_data.at[i, 'bowlers_extras_ratios'] = train_data['bowlers_extras_1'][i] / train_data['bowlers_extras_2'][i]
    
    
    # filling team win% against each other in last 10 games
    team1_id = train_data['team1_id'][i]
    team2_id = train_data['team2_id'][i]
    date = train_data['match_dt'][i]
    
    train_data.at[i, 'team1_winp_team2_last10'] = winpCrossLastn(team1_id, team2_id, date, 10)

            
    # filling team average scores
    team1_id = train_data['team1_id'][i]
    team2_id = train_data['team2_id'][i]
    
    if team1_id in team_avg:
        train_data.at[i, 'team1_average_score'] = team_avg[team1_id]
    else:
        train_data.at[i, 'team1_average_score'] = 0
    if team2_id in team_avg:
        train_data.at[i, 'team2_average_score'] = team_avg[team2_id]
    else:
        train_data.at[i, 'team2_average_score'] = 0
        
    # filling win% of team1 in last 15 games from matchscore_updated
    
    train_data.at[i, 'win_percentage_team1_last_15'] = win_percentage_last_n_matches(team1_id, date, 15)
    train_data.at[i, 'win_percentage_team2_last_15'] = win_percentage_last_n_matches(team2_id, date, 15)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:45: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '10.333333333333334' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'batsmens_averages_1'] += batsman_avg[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '93.93939393939394' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'batsmens_strike_rates_1'] += batsman_sr[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '28.535714285714285' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'bowlers_strike_rates_1'] += bowler_sr[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:49: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '8.060243902439025' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'bowlers_economy_1'] += bowler_economy[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:50: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.03629536921151439' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'bowlers_extras_1'] += bowler_extras[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:56: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '29.384615384615383' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'batsmens_averages_2'] += batsman_avg[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '115.06024096385543' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'batsmens_strike_rates_2'] += batsman_sr[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:59: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '14.142857142857142' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'bowlers_strike_rates_2'] += bowler_sr[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:60: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.805238095238095' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'bowlers_economy_2'] += bowler_economy[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:61: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.03282828282828283' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'bowlers_extras_2'] += bowler_extras[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:79: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2.028272251466206' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'batsmens_averages_ratios'] = train_data['batsmens_averages_1'][i] / train_data['batsmens_averages_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2.611097682281717' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'batsmens_strike_rates_ratios'] = train_data['batsmens_strike_rates_1'][i] / train_data['batsmens_strike_rates_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:81: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4.6388046215074725' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'bowlers_strike_rates_ratios'] = train_data['bowlers_strike_rates_1'][i] / train_data['bowlers_strike_rates_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:82: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2.3510677335280366' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'bowlers_economy_ratios'] = train_data['bowlers_economy_1'][i] / train_data['bowlers_economy_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:83: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.7108938859307787' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'bowlers_extras_ratios'] = train_data['bowlers_extras_1'][i] / train_data['bowlers_extras_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:99: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '137.66666666666666' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'team1_average_score'] = team_avg[team1_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:103: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '116.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'team2_average_score'] = team_avg[team2_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '63.63636363636363' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'win_percentage_team2_last_15'] = win_percentage_last_n_matches(team2_id, date, 15)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '53.333333333333336' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'win_percentage_team1_last_15'] = win_percentage_last_n_matches(team1_id, date, 15)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\81373853.py:91: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '33.33' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[i, 'team1_winp_team2_last10'] = winpCrossLastn(team1_id, team2_id, date, 10)

# %%
# dropping team1_roster_ids , team2_roster_ids , winner , team1 , team2 ,  columns 
train_data = train_data.drop(['team1_roster_ids', 'team2_roster_ids', 'winner', 'team1', 'team2','batsmens_averages_1','batsmens_strike_rates_1','bowlers_strike_rates_1','bowlers_economy_1','bowlers_extras_1','batsmens_averages_2','batsmens_strike_rates_2','bowlers_strike_rates_2','bowlers_economy_2','bowlers_extras_2'], axis=1)

# %%
train_data.head(2)
# Out:
#    match id  team1_id  team2_id  winner_id toss winner toss decision  \
# 0   9331181     11283     12634      12634       Hl Ph         field
# 1   8797060        20        41         20       Wt Is         field
#
#          venue        city    match_dt         lighting     series_name  \
# 0  Hr Ct Sm Ie      Indore  2022-10-20  day/night match     Sd Mq Ai Ty
# 1  Kn Ol Bn Bs  Bridgetown  2022-01-23  day/night match  Ed tr of Wt Is
#
#     season  ground_id  team_count_50runs_last15  team_winp_last5  \
# 0  2022/23       7398                  1.666667         0.672131
# 1  2021/22       1406                  1.285714         1.952381
#
#    team1only_avg_runs_last15  team1_winp_team2_last15  ground_avg_runs_last15  \
# 0                      139.0                    100.0              157.178571
# 1                      156.0                     50.0              103.500000
#
#    batsmens_averages_ratios  batsmens_strike_rates_ratios  \
# 0                  2.028272                      2.611098
# 1                  1.024794                      0.966568
#
#    bowlers_strike_rates_ratios  bowlers_economy_ratios  bowlers_extras_ratios  \
# 0                     4.638805                2.351068               1.710894
# 1                     0.797703                0.807080               0.374242
#
#    team1_winp_team2_last10  team1_average_score  team2_average_score  \
# 0                    100.0           137.666667           116.500000
# 1                     50.0           157.730769           157.791667
#
#    win_percentage_team1_last_15  win_percentage_team2_last_15
# 0                          60.0                     63.636364
# 1                          60.0                     40.000000

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# List of categorical columns to encode
categorical_columns = ['toss winner', 'toss decision', 'venue', 'match_dt', 'lighting', 'series_name', 'season', 'city']

# Initialize the label encoder
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
for col in categorical_columns:
    train_data[col] = label_encoder.fit_transform(train_data[col])

# Display the first 5 rows of the dataframe
train_data.head(5)
# Out:
#    match id  team1_id  team2_id  winner_id  toss winner  toss decision  venue  \
# 0   9331181     11283     12634      12634           44              1     44
# 1   8797060        20        41         20          138              1     53
# 2   9433269     10576      8987      10576           81              1    111
# 3   9587073     36084     36070      36084           34              0     10
# 4   9516457     30407     48341      48341           40              1     75
#
#    city  match_dt  lighting  series_name  season  ground_id  \
# 0    55       212         1           58       2       7398
# 1    13        20         1           22       0       1406
# 2    83       370         1           79       3        251
# 3   105       434         0           18       3      14300
# 4    25       331         2           35       3       7118
#
#    team_count_50runs_last15  team_winp_last5  team1only_avg_runs_last15  \
# 0                  1.666667         0.672131                 139.000000
# 1                  1.285714         1.952381                 156.000000
# 2                  0.857143         0.672131                 173.266667
# 3                  2.166667         1.975610                 164.266667
# 4                  0.818182         1.327869                 164.666667
#
#    team1_winp_team2_last15  ground_avg_runs_last15  batsmens_averages_ratios  \
# 0                    100.0              157.178571                  2.028272
# 1                     50.0              103.500000                  1.024794
# 2                      0.0              154.333333                  1.000138
# 3                     50.0              144.250000                  1.116102
# 4                      0.0              189.000000                  1.035394
#
#    batsmens_strike_rates_ratios  bowlers_strike_rates_ratios  \
# 0                      2.611098                     4.638805
# 1                      0.966568                     0.797703
# 2                      0.909712                     0.850190
# 3                      1.052218                     0.813452
# 4                      1.240634                     1.084338
#
#    bowlers_economy_ratios  bowlers_extras_ratios  team1_winp_team2_last10  \
# 0                2.351068               1.710894                    100.0
# 1                0.807080               0.374242                     50.0
# 2                0.717828               1.024538                      0.0
# 3                0.878287               0.700727                     50.0
# 4                1.168234               1.480742                      0.0
#
#    team1_average_score  team2_average_score  win_percentage_team1_last_15  \
# 0           137.666667           116.500000                     60.000000
# 1           157.730769           157.791667                     60.000000
# 2           166.944444           149.588235                     40.000000
# 3           156.300000           177.076923                     60.000000
# 4           172.400000           167.916667                     53.333333
#
#    win_percentage_team2_last_15
# 0                     63.636364
# 1                     40.000000
# 2                     46.666667
# 3                     66.666667
# 4                     69.230769

# %%
# filling nan values with 0

train_data.fillna(0, inplace=True)

# %%
# changing column names of match id to match_id , toss winner to toss_winner , toss decision to toss_decision

train_data['match_id'] = train_data['match id']
train_data['toss_winner'] = train_data['toss winner']
train_data['toss_decision'] = train_data['toss decision']

train_data = train_data.drop(['match id', 'toss winner', 'toss decision'], axis=1)

# %% [markdown]
# ## For test data also

# %%
# from geopy.geocoders import Nominatim

# # Initialize Nominatim API
# geolocator = Nominatim(user_agent="my_geocoder")

# Creating new columns in test_data and initializing with 0
test_data['batsmens_averages_1'] = 0
test_data['batsmens_strike_rates_1'] = 0
test_data['bowlers_strike_rates_1'] = 0
test_data['bowlers_economy_1'] = 0
test_data['bowlers_extras_1'] = 0

test_data['batsmens_averages_2'] = 0
test_data['batsmens_strike_rates_2'] = 0
test_data['bowlers_strike_rates_2'] = 0
test_data['bowlers_economy_2'] = 0
test_data['bowlers_extras_2'] = 0

test_data['batsmens_averages_ratios'] = 0
test_data['batsmens_strike_rates_ratios'] = 0
test_data['bowlers_strike_rates_ratios'] = 0
test_data['bowlers_economy_ratios'] = 0
test_data['bowlers_extras_ratios'] = 0

test_data['team1_winp_team2_last10']=0
test_data['team1_average_score'] = 0
test_data['team2_average_score'] = 0
test_data['win_percentage_team1_last_15'] = 0
test_data['win_percentage_team2_last_15'] = 0


# test_data['location_humidity'] = 0
# test_data['location_temperature'] = 0

# Filling the values in the new columns
for i in range(len(test_data)):
    # Getting ids of batsmen and bowlers from team roster id separated by :
    team1_players_ids = test_data['team1_roster_ids'][i].split(':')
    team2_players_ids = test_data['team2_roster_ids'][i].split(':')
    # print(i,team1_players_ids,team2_players_ids)
    # For team1 check if id is present in the dictionary and add the values
    for player_id in team1_players_ids:
        player_id = int(float(player_id))
        if player_id in batsman_avg:
            test_data.at[i, 'batsmens_averages_1'] += batsman_avg[player_id]
            test_data.at[i, 'batsmens_strike_rates_1'] += batsman_sr[player_id]
        if player_id in bowler_sr:
            test_data.at[i, 'bowlers_strike_rates_1'] += bowler_sr[player_id]
            test_data.at[i, 'bowlers_economy_1'] += bowler_economy[player_id]
            test_data.at[i, 'bowlers_extras_1'] += bowler_extras[player_id]
            
    # For team2 check if id is present in the dictionary and add the values
    for player_id in team2_players_ids:
        player_id = int(float(player_id))
        if player_id in batsman_avg:
            test_data.at[i, 'batsmens_averages_2'] += batsman_avg[player_id]
            test_data.at[i, 'batsmens_strike_rates_2'] += batsman_sr[player_id]
        if player_id in bowler_sr:
            test_data.at[i, 'bowlers_strike_rates_2'] += bowler_sr[player_id]
            test_data.at[i, 'bowlers_economy_2'] += bowler_economy[player_id]
            test_data.at[i, 'bowlers_extras_2'] += bowler_extras[player_id]
    
    # filling ratios
    if test_data['batsmens_averages_2'][i] == 0:
        test_data['batsmens_averages_2'][i] = 1
        
    if test_data['batsmens_strike_rates_2'][i] == 0:
        test_data['batsmens_strike_rates_2'][i] = 1
    if test_data['bowlers_strike_rates_2'][i] == 0:
        test_data['bowlers_strike_rates_2'][i] = 1
        
    if test_data['bowlers_economy_2'][i] == 0:
        test_data['bowlers_economy_2'][i] = 1
        
    if test_data['bowlers_extras_2'][i] == 0:
        test_data['bowlers_extras_2'][i] = 1
        
    
    test_data.at[i, 'batsmens_averages_ratios'] = test_data['batsmens_averages_1'][i] / test_data['batsmens_averages_2'][i]
    test_data.at[i, 'batsmens_strike_rates_ratios'] = test_data['batsmens_strike_rates_1'][i] / test_data['batsmens_strike_rates_2'][i]
    test_data.at[i, 'bowlers_strike_rates_ratios'] = test_data['bowlers_strike_rates_1'][i] / test_data['bowlers_strike_rates_2'][i]
    test_data.at[i, 'bowlers_economy_ratios'] = test_data['bowlers_economy_1'][i] / test_data['bowlers_economy_2'][i]
    test_data.at[i, 'bowlers_extras_ratios'] = test_data['bowlers_extras_1'][i] / test_data['bowlers_extras_2'][i]
    
    
    # filling team win% against each other in last 10 games
    team1_id = test_data['team1_id'][i]
    team2_id = test_data['team2_id'][i]
    date = test_data['match_dt'][i]
    
    test_data.at[i, 'team1_winp_team2_last10'] = winpCrossLastn(team1_id, team2_id, date, 10)

            
    # filling team average scores
    team1_id = test_data['team1_id'][i]
    team2_id = test_data['team2_id'][i]
    
    if team1_id in team_avg:
        test_data.at[i, 'team1_average_score'] = team_avg[team1_id]
    else:
        test_data.at[i, 'team1_average_score'] = 0
    if team2_id in team_avg:
        test_data.at[i, 'team2_average_score'] = team_avg[team2_id]
    else:
        test_data.at[i, 'team2_average_score'] = 0
        
    # filling win% of team1 in last 15 games from matchscore_updated
    
    test_data.at[i, 'win_percentage_team1_last_15'] = win_percentage_last_n_matches(team1_id, date, 15)
    test_data.at[i, 'win_percentage_team2_last_15'] = win_percentage_last_n_matches(team2_id, date, 15)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:45: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '16.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'batsmens_averages_1'] += batsman_avg[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '147.27272727272725' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'batsmens_strike_rates_1'] += batsman_sr[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:49: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4.25' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'bowlers_economy_1'] += bowler_economy[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:50: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.041666666666666664' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'bowlers_extras_1'] += bowler_extras[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:56: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '29.6' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'batsmens_averages_2'] += batsman_avg[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '129.82456140350877' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'batsmens_strike_rates_2'] += batsman_sr[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:60: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '5.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'bowlers_economy_2'] += bowler_economy[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:59: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '10.666666666666666' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'bowlers_strike_rates_2'] += bowler_sr[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:61: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.03125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'bowlers_extras_2'] += bowler_extras[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:79: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.580852932565629' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'batsmens_averages_ratios'] = test_data['batsmens_averages_1'][i] / test_data['batsmens_averages_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.44369772245797456' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'batsmens_strike_rates_ratios'] = test_data['batsmens_strike_rates_1'][i] / test_data['batsmens_strike_rates_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:81: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9627023223082337' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'bowlers_strike_rates_ratios'] = test_data['bowlers_strike_rates_1'][i] / test_data['bowlers_strike_rates_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:82: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.43947943881604273' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'bowlers_economy_ratios'] = test_data['bowlers_economy_1'][i] / test_data['bowlers_economy_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:83: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.313131313131313' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'bowlers_extras_ratios'] = test_data['bowlers_extras_1'][i] / test_data['bowlers_extras_2'][i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:103: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '144.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'team2_average_score'] = team_avg[team2_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '17.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'bowlers_strike_rates_1'] += bowler_sr[player_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:91: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '66.67' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'team1_winp_team2_last10'] = winpCrossLastn(team1_id, team2_id, date, 10)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:99: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '156.3' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'team1_average_score'] = team_avg[team1_id]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '33.33333333333333' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'win_percentage_team1_last_15'] = win_percentage_last_n_matches(team1_id, date, 15)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '33.33333333333333' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_data.at[i, 'win_percentage_team2_last_15'] = win_percentage_last_n_matches(team2_id, date, 15)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['bowlers_extras_2'][i] = 1
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22904\3917223969.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['bowlers_extras_2'][i] = 1

# %%
# dropping team1_roster_ids , team2_roster_ids , winner , team1 , team2 ,  columns 
test_data = test_data.drop(['team1_roster_ids', 'team2_roster_ids','team1', 'team2','batsmens_averages_1','batsmens_strike_rates_1','bowlers_strike_rates_1','bowlers_economy_1','bowlers_extras_1','batsmens_averages_2','batsmens_strike_rates_2','bowlers_strike_rates_2','bowlers_economy_2','bowlers_extras_2'], axis=1)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# List of categorical columns to encode
categorical_columns = ['toss winner', 'toss decision', 'venue', 'match_dt', 'lighting', 'series_name', 'season', 'city']

# Initialize the label encoder
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
for col in categorical_columns:
    test_data[col] = label_encoder.fit_transform(test_data[col])

# Display the first 5 rows of the dataframe
test_data.head(5)
# Out:
#    match id  team1_id  team2_id  toss winner  toss decision  venue  city  \
# 0   9250275     28594        90          104              1     11    13
# 1   9262189     36084     36098           40              1     59    70
# 2   9128776     30428     48334           82              0      8    58
# 3   9586919     36098     36112           92              1     23    38
# 4   9128538     30414     48341           31              1     46    71
#
#    match_dt  lighting  series_name  season  ground_id  \
# 0        69         0           49       1       3226
# 1       146         2           11       1      13915
# 2        97         2           18       1       2764
# 3       107         2           11       3      11892
# 4       113         2           18       1      18752
#
#    team_count_50runs_last15  team_winp_last5  team1only_avg_runs_last15  \
# 0                  0.000000         0.019608                        NaN
# 1                  0.615385         0.344262                 151.285714
# 2                  0.842105         0.753086                 171.066667
# 3                  0.285714         1.487805                 166.000000
# 4                  2.375000         0.310330                 169.933333
#
#    team1_winp_team2_last15  ground_avg_runs_last15  batsmens_averages_ratios  \
# 0                     0.00                     NaN                  0.580853
# 1                    66.67                 153.500                  1.089279
# 2                   100.00                 179.625                  1.080138
# 3                    75.00                 155.500                  0.871249
# 4                     0.00                 164.125                  1.107382
#
#    batsmens_strike_rates_ratios  bowlers_strike_rates_ratios  \
# 0                      0.443698                     0.962702
# 1                      1.091648                     0.840087
# 2                      0.955992                     0.771592
# 3                      0.848296                     0.845522
# 4                      1.166437                     0.963643
#
#    bowlers_economy_ratios  bowlers_extras_ratios  team1_winp_team2_last10  \
# 0                0.439479               1.313131                     0.00
# 1                0.961859               0.787592                    66.67
# 2                0.993761               0.900654                     0.00
# 3                0.870841               0.731058                     0.00
# 4                1.001825               0.946688                     0.00
#
#    team1_average_score  team2_average_score  win_percentage_team1_last_15  \
# 0           141.000000           144.500000                           0.0
# 1           156.300000           148.125000                          60.0
# 2           168.142857           159.400000                           0.0
# 3           148.125000           166.800000                           0.0
# 4           165.307692           167.916667                           0.0
#
#    win_percentage_team2_last_15
# 0                           0.0
# 1                          40.0
# 2                           0.0
# 3                           0.0
# 4                           0.0

# %%
# filling nan values with 0

test_data.fillna(0, inplace=True)

# %%
# changing column names of match id to match_id , toss winner to toss_winner , toss decision to toss_decision

test_data['match_id'] = test_data['match id']
test_data['toss_winner'] = test_data['toss winner']
test_data['toss_decision'] = test_data['toss decision']

test_data = test_data.drop(['match id', 'toss winner', 'toss decision'], axis=1)

# %%
test_data.head(15)
# Out:
#     team1_id  team2_id  venue  city  match_dt  lighting  series_name  season  \
# 0      28594        90     11    13        69         0           49       1
# 1      36084     36098     59    70       146         2           11       1
# 2      30428     48334      8    58        97         2           18       1
# 3      36098     36112     23    38       107         2           11       3
# 4      30414     48341     46    71       113         2           18       1
# 5      30407     30435     57    20        17         2           18       3
# 6      36014     30414     45    23       142         2           18       3
# 7       9701      6698     81    81        58         2           50       1
# 8       7727      7573     82    76       208         1           50       3
# 9      30428     36014     67    42         8         1           18       3
# 10     36098     38814     61    68        89         0           11       1
# 11       202       272     91    32       162         2           48       3
# 12     47487     47501     63    26       164         2           20       2
# 13        48       202     22    33       119         2           29       3
# 14       188        62     38    25        83         0           33       2
#
#     ground_id  team_count_50runs_last15  team_winp_last5  \
# 0        3226                  0.000000         0.019608
# 1       13915                  0.615385         0.344262
# 2        2764                  0.842105         0.753086
# 3       11892                  0.285714         1.487805
# 4       18752                  2.375000         0.310330
# 5        7118                  0.400000         0.672131
# 6        2050                  0.681818         0.344262
# 7        1042                  3.200000         0.603960
# 8        8301                  2.428571         2.904762
# 9       13880                  1.727273        21.000000
# 10       1469                  1.714286         1.487805
# 11      20502                  1.500000         1.952381
# 12       7041                  0.600000         0.506173
# 13      17086                  3.400000         1.487805
# 14        664                  0.444444         0.024390
#
#     team1only_avg_runs_last15  team1_winp_team2_last15  \
# 0                    0.000000                     0.00
# 1                  151.285714                    66.67
# 2                  171.066667                   100.00
# 3                  166.000000                    75.00
# 4                  169.933333                     0.00
# 5                  177.066667                    50.00
# 6                  183.466667                    25.00
# 7                  163.066667                     0.00
# 8                  167.000000                   100.00
# 9                  171.066667                    66.67
# 10                 168.800000                    66.67
# 11                 157.333333                     0.00
# 12                 158.200000                     0.00
# 13                 176.066667                     0.00
# 14                 140.533333                     0.00
#
#     ground_avg_runs_last15  batsmens_averages_ratios  \
# 0                 0.000000                  0.580853
# 1               153.500000                  1.089279
# 2               179.625000                  1.080138
# 3               155.500000                  0.871249
# 4               164.125000                  1.107382
# 5               184.500000                  0.941093
# 6               156.350000                  0.921257
# 7               177.321429                  0.937888
# 8               151.600000                  1.301483
# 9               186.500000                  1.161314
# 10              134.000000                  0.946698
# 11              140.500000                  1.012518
# 12              132.000000                  1.031492
# 13              144.933333                  1.604579
# 14              156.633333                  0.589116
#
#     batsmens_strike_rates_ratios  bowlers_strike_rates_ratios  \
# 0                       0.443698                     0.962702
# 1                       1.091648                     0.840087
# 2                       0.955992                     0.771592
# 3                       0.848296                     0.845522
# 4                       1.166437                     0.963643
# 5                       0.995272                     1.001928
# 6                       1.034135                     0.921563
# 7                       1.114808                     0.635880
# 8                       1.165019                     1.046915
# 9                       1.008119                     0.596095
# 10                      0.979051                     1.026418
# 11                      1.010697                     1.538581
# 12                      1.027123                     1.207781
# 13                      1.457516                     1.111371
# 14                      0.807088                     1.172487
#
#     bowlers_economy_ratios  bowlers_extras_ratios  team1_winp_team2_last10  \
# 0                 0.439479               1.313131                     0.00
# 1                 0.961859               0.787592                    66.67
# 2                 0.993761               0.900654                     0.00
# 3                 0.870841               0.731058                     0.00
# 4                 1.001825               0.946688                     0.00
# 5                 0.934268               0.736990                     0.00
# 6                 0.955612               0.797946                    25.00
# 7                 0.685779               1.635887                     0.00
# 8                 0.940972               1.415819                   100.00
# 9                 1.011756               1.146592                     0.00
# 10                0.973538               1.186959                     0.00
# 11                0.712175               0.753047                     0.00
# 12                1.138782               1.351469                     0.00
# 13                1.384021               2.114873                     0.00
# 14                1.405161               1.686281                     0.00
#
#     team1_average_score  team2_average_score  win_percentage_team1_last_15  \
# 0            141.000000           144.500000                      0.000000
# 1            156.300000           148.125000                     60.000000
# 2            168.142857           159.400000                      0.000000
# 3            148.125000           166.800000                      0.000000
# 4            165.307692           167.916667                      0.000000
# 5            172.400000           169.307692                      0.000000
# 6            170.000000           165.307692                     33.333333
# 7            159.500000           165.857143                      0.000000
# 8            158.000000           159.312500                     80.000000
# 9            168.142857           170.000000                      0.000000
# 10           148.125000           172.000000                      0.000000
# 11           147.100000           129.500000                     53.333333
# 12           152.769231           131.333333                     33.333333
# 13           143.176471           147.100000                      0.000000
# 14           136.318182           159.916667                      0.000000
#
#     win_percentage_team2_last_15  match_id  toss_winner  toss_decision
# 0                       0.000000   9250275          104              1
# 1                      40.000000   9262189           40              1
# 2                       0.000000   9128776           82              0
# 3                       0.000000   9586919           92              1
# 4                       0.000000   9128538           31              1
# 5                       0.000000   9516653           57              1
# 6                      60.000000   9516534           12              1
# 7                       0.000000   9085474           19              1
# 8                      40.000000   9433752           30              1
# 9                       0.000000   9516359           89              1
# 10                      0.000000   9262133           91              1
# 11                     33.333333   9782086          103              0
# 12                     53.333333   9271807           39              1
# 13                      0.000000   9644102          103              1
# 14                      0.000000   9256386            6              0

# %%
train_data.shape
test_data.shape
# Out:
# (948, 28)
# (271, 27)

# %%
new_test_data = test_data

# %%
new_train_data=train_data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from sklearn.ensemble import GradientBoostingClassifier
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler

X_train = train_data.drop(['winner_id'], axis=1)
y_train = train_data['winner_id']

X_test = test_data

# %%
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE

# %%
unique_classes = np.unique(y_train)
single_occurrence_classes = [c for c in unique_classes if np.sum(y_train == c) == 1]

# Oversample each single-occurrence class to 8 instances
oversampled_X_train = []

oversampled_y = []
for class_label in single_occurrence_classes:
    class_X_train = X_train[y_train == class_label]
    class_y = y_train[y_train == class_label]
    oversampled_X_train.extend([class_X_train] * (8 - len(class_X_train)))
    oversampled_y.extend([class_y] * (8 - len(class_y)))

# Concatenate the oversampled data with the original data
X_train_resampled = np.concatenate([X_train] + oversampled_X_train)
y_resampled = np.concatenate([y_train] + oversampled_y)

# %%
# i79 = np.where(y_test == 79)[0][0]
# i79

# %%
# Initialize SMOTE
smote = SMOTE(random_state=101, k_neighbors=1)

# Apply SMOTE to the entire dataset
X_train, y_train = smote.fit_resample(X_train_resampled, y_resampled)

# %%
# Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:458: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
# CatBoost
cat_model = CatBoostClassifier()
cat_model.fit(X_train, y_train)

# cat_accuracy = accuracy_score(y_test, cat_pred)
# cat_f1 = f1_score(y_test, cat_pred, average='macro')
# Out:
# Learning rate set to 0.084957
# 0:	learn: 4.7340856	total: 953ms	remaining: 15m 52s
# 1:	learn: 4.5765950	total: 1.75s	remaining: 14m 34s
# 2:	learn: 4.3849563	total: 2.47s	remaining: 13m 42s
# 3:	learn: 4.1641418	total: 3.19s	remaining: 13m 13s
# 4:	learn: 3.9643694	total: 3.89s	remaining: 12m 53s
# 5:	learn: 3.7966947	total: 4.64s	remaining: 12m 48s
# 6:	learn: 3.6283499	total: 5.39s	remaining: 12m 45s
# 7:	learn: 3.4414321	total: 6.11s	remaining: 12m 38s
# 8:	learn: 3.2603879	total: 6.84s	remaining: 12m 33s
# 9:	learn: 3.0939965	total: 7.54s	remaining: 12m 26s
# 10:	learn: 2.9584906	total: 8.4s	remaining: 12m 35s
# 11:	learn: 2.8240776	total: 9.16s	remaining: 12m 33s
# 12:	learn: 2.7192045	total: 9.9s	remaining: 12m 31s
# 13:	learn: 2.6205383	total: 10.6s	remaining: 12m 28s
# 14:	learn: 2.5140818	total: 11.4s	remaining: 12m 25s
# 15:	learn: 2.4144644	total: 12.2s	remaining: 12m 27s
# 16:	learn: 2.3048200	total: 12.9s	remaining: 12m 25s
# 17:	learn: 2.2112091	total: 13.7s	remaining: 12m 26s
# 18:	learn: 2.1317369	total: 14.4s	remaining: 12m 25s
# 19:	learn: 2.0544505	total: 15.2s	remaining: 12m 25s
# 20:	learn: 1.9867445	total: 16s	remaining: 12m 25s
# 21:	learn: 1.9171264	total: 16.7s	remaining: 12m 22s
# 22:	learn: 1.8569146	total: 17.4s	remaining: 12m 18s
# 23:	learn: 1.7960118	total: 18.1s	remaining: 12m 16s
# 24:	learn: 1.7381056	total: 18.8s	remaining: 12m 14s
# 25:	learn: 1.6753214	total: 19.6s	remaining: 12m 15s
# 26:	learn: 1.6242125	total: 20.4s	remaining: 12m 13s
# 73:	learn: 0.5557451	total: 55.3s	remaining: 11m 31s
# 74:	learn: 0.5467031	total: 56.1s	remaining: 11m 32s
# 75:	learn: 0.5371708	total: 56.9s	remaining: 11m 31s
# 76:	learn: 0.5296366	total: 57.7s	remaining: 11m 31s
# 77:	learn: 0.5210808	total: 58.5s	remaining: 11m 31s
# 78:	learn: 0.5140729	total: 59.2s	remaining: 11m 30s
# 79:	learn: 0.5075129	total: 59.9s	remaining: 11m 29s
# 80:	learn: 0.4988177	total: 1m	remaining: 11m 29s
# 81:	learn: 0.4910575	total: 1m 1s	remaining: 11m 28s
# 82:	learn: 0.4845908	total: 1m 2s	remaining: 11m 27s
# 83:	learn: 0.4774998	total: 1m 2s	remaining: 11m 26s
# 84:	learn: 0.4701251	total: 1m 3s	remaining: 11m 25s
# 85:	learn: 0.4628783	total: 1m 4s	remaining: 11m 25s
# 86:	learn: 0.4555696	total: 1m 5s	remaining: 11m 24s
# 87:	learn: 0.4492958	total: 1m 5s	remaining: 11m 23s
# 88:	learn: 0.4417938	total: 1m 6s	remaining: 11m 23s
# 89:	learn: 0.4348516	total: 1m 7s	remaining: 11m 23s
# 90:	learn: 0.4285546	total: 1m 8s	remaining: 11m 23s
# 91:	learn: 0.4240566	total: 1m 9s	remaining: 11m 22s
# 92:	learn: 0.4177707	total: 1m 9s	remaining: 11m 22s
# 93:	learn: 0.4116884	total: 1m 10s	remaining: 11m 22s
# 94:	learn: 0.4067641	total: 1m 11s	remaining: 11m 23s
# 95:	learn: 0.4007266	total: 1m 12s	remaining: 11m 23s
# 96:	learn: 0.3955195	total: 1m 13s	remaining: 11m 22s
# 97:	learn: 0.3894304	total: 1m 14s	remaining: 11m 22s
# 98:	learn: 0.3858244	total: 1m 14s	remaining: 11m 21s

# %%
test_data.shape
# Out:
# (271, 29)

# %%
X_test.shape
# Out:
# (271, 27)

# %%
new_test_data.head(5)
# Out:
#    team1_id  team2_id  venue  city  match_dt  lighting  series_name  season  \
# 0     28594        90     11    13        69         0           49       1
# 1     36084     36098     59    70       146         2           11       1
# 2     30428     48334      8    58        97         2           18       1
# 3     36098     36112     23    38       107         2           11       3
# 4     30414     48341     46    71       113         2           18       1
#
#    ground_id  team_count_50runs_last15  team_winp_last5  \
# 0       3226                  0.000000         0.019608
# 1      13915                  0.615385         0.344262
# 2       2764                  0.842105         0.753086
# 3      11892                  0.285714         1.487805
# 4      18752                  2.375000         0.310330
#
#    team1only_avg_runs_last15  team1_winp_team2_last15  ground_avg_runs_last15  \
# 0                   0.000000                     0.00                   0.000
# 1                 151.285714                    66.67                 153.500
# 2                 171.066667                   100.00                 179.625
# 3                 166.000000                    75.00                 155.500
# 4                 169.933333                     0.00                 164.125
#
#    batsmens_averages_ratios  batsmens_strike_rates_ratios  \
# 0                  0.580853                      0.443698
# 1                  1.089279                      1.091648
# 2                  1.080138                      0.955992
# 3                  0.871249                      0.848296
# 4                  1.107382                      1.166437
#
#    bowlers_strike_rates_ratios  bowlers_economy_ratios  bowlers_extras_ratios  \
# 0                     0.962702                0.439479               1.313131
# 1                     0.840087                0.961859               0.787592
# 2                     0.771592                0.993761               0.900654
# 3                     0.845522                0.870841               0.731058
# 4                     0.963643                1.001825               0.946688
#
#    team1_winp_team2_last10  team1_average_score  team2_average_score  \
# 0                     0.00           141.000000           144.500000
# 1                    66.67           156.300000           148.125000
# 2                     0.00           168.142857           159.400000
# 3                     0.00           148.125000           166.800000
# 4                     0.00           165.307692           167.916667
#
#    win_percentage_team1_last_15  win_percentage_team2_last_15  match_id  \
# 0                           0.0                           0.0   9250275
# 1                          60.0                          40.0   9262189
# 2                           0.0                           0.0   9128776
# 3                           0.0                           0.0   9586919
# 4                           0.0                           0.0   9128538
#
#    toss_winner  toss_decision  win_pred_team_id  win_pred_score
# 0          104              1                90        0.000871
# 1           40              1             36084        0.134157
# 2           82              0             30428        0.062006
# 3           92              1             36112        0.034009
# 4           31              1             48341        0.272571

# %%
team1_ids = new_test_data['team1_id']
team2_ids = new_test_data['team2_id']

# %%
cat_preds = cat_model.predict_proba(X_test)

unique_classes = np.unique(y_train)
class_to_index = {label: idx for idx, label in enumerate(unique_classes)}
y_train_indexed = np.array([class_to_index[label] for label in y_train])

# Compare probabilities and assign the team with higher probability
cat_y_pred_01 = []
cat_win_prob = []
for i in range(len(cat_preds)):
    team1_id = team1_ids[i]
    team2_id = team2_ids[i]

    team1_index = class_to_index.get(team1_id, -1)
    team2_index = class_to_index.get(team2_id, -1)

    if team1_index == -1 and team2_index == -1:
        cat_y_pred_01.append(team1_id)
        cat_win_prob.append(0)

        continue
        # raise ValueError(f"Team ID {team1_id} or {team2_id} not found in class_to_index mapping.")

    team1_prob = cat_preds[i][team1_index]  # Probability for team1_id
    team2_prob = cat_preds[i][team2_index]  # Probability for team2_id

    if team1_prob > team2_prob:
        cat_y_pred_01.append(team1_id)  # team1_id
        cat_win_prob.append(team1_prob)
    else:
        cat_y_pred_01.append(team2_id)  # team2_id
        cat_win_prob.append(team2_prob)

# %%
# printing winning team along with their winning probability
for i in range(len(cat_y_pred_01)):
    print(f"Match {i+1}: {cat_y_pred_01[i]} with probability {cat_win_prob[i]}")
# Out:
# Match 1: 90 with probability 0.0013430374871913082
# Match 2: 36084 with probability 0.13415652138673856
# Match 3: 30428 with probability 0.06251607786198317
# Match 4: 36112 with probability 0.05104069811402093
# Match 5: 48341 with probability 0.2725709038449679
# Match 6: 30407 with probability 0.5576064771718952
# Match 7: 30414 with probability 0.21736723002828165
# Match 8: 6698 with probability 0.1651782358901129
# Match 9: 7727 with probability 0.07516110228872606
# Match 10: 36014 with probability 0.020048325671559026
# Match 11: 36098 with probability 0.23988541911740566
# Match 12: 202 with probability 0.3557548977794818
# Match 13: 47501 with probability 0.15600063863272026
# Match 14: 48 with probability 0.319525427084894
# Match 15: 62 with probability 0.5702257812613878
# Match 16: 33963 with probability 0.06563858974347496
# Match 17: 6698 with probability 0.26987828846549106
# Match 18: 20 with probability 0.22733778115235784
# Match 19: 36070 with probability 0.39124442980629953
# Match 20: 36070 with probability 0.05501404034292352
# Match 21: 48341 with probability 0.12327247574167267
# Match 22: 10366 with probability 0.07442934284567654
# Match 23: 33942 with probability 0.32547601649569413
# Match 24: 42573 with probability 0.06522056579905806
# Match 25: 9701 with probability 0.13763986236301332
# Match 26: 30414 with probability 0.2998775606532155
# Match 27: 45926 with probability 0
# Match 28: 251 with probability 0.03577622036238401
# Match 29: 8987 with probability 0.22891194971767628
# Match 30: 7258 with probability 0.030405934950652254
# Match 234: 46731 with probability 0.27553189912113174
# Match 235: 40606 with probability 0.33188385734681575
# Match 236: 272 with probability 0.22672250876696767
# Match 237: 251 with probability 0.03398415411940542
# Match 238: 33956 with probability 0.5234828707396091
# Match 239: 40578 with probability 0.06281848770373637
# Match 240: 23869 with probability 0.665366938721974
# Match 241: 22763 with probability 0.004527610139754632
# Match 242: 46745 with probability 0.01636699716060135
# Match 243: 8987 with probability 0.28136523060164187
# Match 244: 33914 with probability 0.612052208808799
# Match 245: 48 with probability 0.38619690281461605
# Match 246: 40578 with probability 0.05637270181569957
# Match 247: 40578 with probability 0.06259574147674254
# Match 248: 46773 with probability 0.06499840068712351
# Match 249: 237 with probability 0.13351890636551597
# Match 250: 30400 with probability 0.5445266240318354
# Match 251: 27 with probability 0.9280465385710815
# Match 252: 33921 with probability 0.5149120279895751
# Match 253: 10618 with probability 0.10850618688147443
# Match 254: 30400 with probability 0.034201952696172225
# Match 255: 40606 with probability 0.1626456309209102
# Match 256: 33928 with probability 0.453784865633903
# Match 257: 30428 with probability 0.2605195243267626
# Match 258: 23113 with probability 0.003028608907479151
# Match 259: 36084 with probability 0.07753796622664173
# Match 260: 9876 with probability 0.136191480784015
# Match 261: 251 with probability 0.03389042767176494
# Match 262: 23750 with probability 0.8505528662121956
# Match 263: 36098 with probability 0.04329794571649672
# Match 264: 15497 with probability 0.3459353055343221
# Match 265: 33921 with probability 0.8453859888077433
# Match 266: 55 with probability 0.06759085181918485
# Match 267: 46773 with probability 0.1545718936557072
# Match 268: 69 with probability 0.13812725614637178
# Match 269: 7573 with probability 0.5849941826271248
# Match 270: 33942 with probability 0.40867748813309573
# Match 271: 33928 with probability 0.9268691146452293

# %%
import xgboost as xgb
import numpy as np
import pandas as pd


# Ensure y_train contains zero-indexed integer labels
unique_classes = np.unique(y_train)
class_to_index = {label: idx for idx, label in enumerate(unique_classes)}
y_train_indexed = np.array([class_to_index[label] for label in y_train])

# Create DMatrix for training and testing
xgb_train = xgb.DMatrix(X_train, label=y_train_indexed, enable_categorical=True)
xgb_test = xgb.DMatrix(X_test, enable_categorical=True)  # No label for xgb_test

# Define parameters and add num_class
n = 150
params = {
    'objective': 'multi:softprob',
    'max_depth': 6,
    'learning_rate': 0.1,
    'num_class': len(unique_classes)  # Number of unique classes
}

# Train the model
xgb_model = xgb.train(params=params, dtrain=xgb_train, num_boost_round=n)

# Make predictions
xgb_preds = xgb_model.predict(xgb_test)

# Compare probabilities and assign the team with higher probability
y_pred_01 = []
win_prob=[]
for i in range(len(xgb_preds)):
    team1_id = team1_ids[i]
    team2_id = team2_ids[i]
    
    team1_index = class_to_index.get(team1_id, -1)
    team2_index = class_to_index.get(team2_id, -1)
    
    if team1_index == -1 and team2_index == -1:
        y_pred_01.append(team1_id)
        win_prob.append(0)
        
        continue
        # raise ValueError(f"Team ID {team1_id} or {team2_id} not found in class_to_index mapping.")
    
    team1_prob = xgb_preds[i][team1_index]  # Probability for team1_id
    team2_prob = xgb_preds[i][team2_index]  # Probability for team2_id
    
    if team1_prob > team2_prob:
        y_pred_01.append(team1_id)  # team1_id
        win_prob.append(team1_prob)
    else:
        y_pred_01.append(team2_id)  # team2_id
        win_prob.append(team2_prob)

# Print predictions
# print(f'Predicted class labels for X_test: {y_pred_01}')

# %%
# printing winning team along with their winning probability
for i in range(len(y_pred_01)):
    print(f"Match {i+1}: {y_pred_01[i]} with probability {win_prob[i]}")
# Out:
# Match 1: 28594 with probability 0.007757620420306921
# Match 2: 36098 with probability 0.003110178280621767
# Match 3: 30428 with probability 0.220680832862854
# Match 4: 36112 with probability 0.004472097847610712
# Match 5: 30414 with probability 0.04112886264920235
# Match 6: 30407 with probability 0.06293463706970215
# Match 7: 30414 with probability 0.1516619324684143
# Match 8: 6698 with probability 0.034552719444036484
# Match 9: 7727 with probability 0.010891024954617023
# Match 10: 30428 with probability 0.26741883158683777
# Match 11: 36098 with probability 0.01836247369647026
# Match 12: 272 with probability 0.005053613800555468
# Match 13: 47487 with probability 0.006391638424247503
# Match 14: 48 with probability 0.04245441406965256
# Match 15: 62 with probability 0.02649027481675148
# Match 16: 33963 with probability 0.013009293004870415
# Match 17: 6698 with probability 0.02539064921438694
# Match 18: 41 with probability 0.6000406742095947
# Match 19: 36070 with probability 0.03413557633757591
# Match 20: 36070 with probability 0.003385762218385935
# Match 21: 48334 with probability 0.0061707524582743645
# Match 22: 10366 with probability 0.01369230356067419
# Match 23: 33942 with probability 0.011922688223421574
# Match 24: 42573 with probability 0.007174956612288952
# Match 25: 9701 with probability 0.011004134081304073
# Match 26: 30414 with probability 0.08156991004943848
# Match 27: 45926 with probability 0
# Match 28: 209 with probability 0.0024898091796785593
# Match 29: 8987 with probability 0.05210607498884201
# Match 30: 7258 with probability 0.010155688039958477
# Match 31: 188 with probability 0.0033638584427535534
# Match 32: 47529 with probability 0.03737777844071388
# Match 33: 23750 with probability 0.016416708007454872
# Match 34: 47487 with probability 0.01950916461646557
# Match 35: 27 with probability 0.20298628509044647
# Match 36: 47529 with probability 0.14419202506542206
# Match 37: 7608 with probability 0.021590059623122215
# Match 38: 8987 with probability 0.06082598865032196
# Match 39: 11591 with probability 0.3795199394226074
# Match 40: 33963 with probability 0.37054648995399475
# Match 41: 41 with probability 0.4980693757534027
# Match 42: 30414 with probability 0.06464661657810211
# Match 43: 55 with probability 0.014863936230540276
# Match 44: 47529 with probability 0.5413178205490112
# Match 45: 40298 with probability 0.27140986919403076
# Match 46: 9701 with probability 0.015213514678180218
# Match 47: 47529 with probability 0.02721184492111206
# Match 48: 36126 with probability 0.0021746766287833452
# Match 49: 33928 with probability 0.6549773216247559
# Match 50: 15301 with probability 0.06735106557607651
# Match 51: 11283 with probability 0.06944344192743301
# Match 52: 188 with probability 0.03691451624035835
# Match 53: 12669 with probability 0.02825304865837097
# Match 54: 9701 with probability 0.01010877639055252
# Match 55: 40578 with probability 0.01768481731414795
# Match 56: 47480 with probability 0.0028207150753587484
# Match 57: 40564 with probability 0.007943234406411648
# Match 58: 48922 with probability 0.004894526209682226
# Match 59: 33942 with probability 0.06211920827627182
# Match 60: 62 with probability 0.02912687323987484
# Match 61: 41 with probability 0.0673302486538887
# Match 62: 55 with probability 0.018524792045354843
# Match 266: 41 with probability 0.045401621609926224
# Match 267: 46773 with probability 0.031139984726905823
# Match 268: 55 with probability 0.16693474352359772
# Match 269: 7573 with probability 0.17013725638389587
# Match 270: 33942 with probability 0.1946493238210678
# Match 271: 33928 with probability 0.7717017531394958

# %%
ensemble_pred = []
ensemble_prob = []

for i in range(len(y_pred_01)):
    if(y_pred_01[i] == cat_y_pred_01[i]):
        ensemble_pred.append(y_pred_01[i])
        ensemble_prob.append(0.5 * (cat_win_prob[i] + win_prob[i]))

    elif (cat_win_prob[i] > win_prob[i]):
        ensemble_pred.append(cat_y_pred_01[i])
        ensemble_prob.append(cat_win_prob[i])

    else:
        ensemble_pred.append(y_pred_01[i])
        ensemble_prob.append(win_prob[i])

# %%
ensemble_pred
# Out:
# [28594,
#  36084,
#  30428,
#  36112,
#  48341,
#  30407,
#  30414,
#  6698,
#  7727,
#  30428,
#  36098,
#  202,
#  47501,
#  48,
#  62,
#  33963,
#  6698,
#  41,
#  36070,
#  36070,
#  48341,
#  10366,
#  33942,
#  42573,
#  9701,
#  30414,
#  45926,
#  251,
#  8987,
#  7258,
#  188,
#  47529,
#  23750,
#  47487,
#  27,
#  47529,
#  9967,
#  10576,
#  11591,
#  33963,
#  41,
#  48341,
#  55,
#  47529,
#  40298,
#  9701,
#  40452,
#  36084,
#  33928,
#  15301,
#  11283,
#  293,
#  14454,
#  7258,
#  40578,
#  47480,
#  40564,
#  48922,
#  33942,
#  62,
#  55,
#  55,
#  6698,
#  30421,
#  6698,
#  55,
#  33935,
#  14454,
#  30393,
#  48334,
#  62,
#  7727,
#  12718,
#  188,
#  8056,
#  216,
#  46759,
#  33921,
#  62,
#  30421,
#  33928,
#  188,
#  48733,
#  40298,
#  44904,
#  40550,
#  30428,
#  7608,
#  47508,
#  11591,
#  30421,
#  6698,
#  30393,
#  40298,
#  10618,
#  55,
#  7258,
#  40298,
#  202,
#  10576,
#  216,
#  35790,
#  15497,
#  33921,
#  33942,
#  17583,
#  36084,
#  27,
#  48,
#  7727,
#  40606,
#  8987,
#  30407,
#  20,
#  8987,
#  30428,
#  35790,
#  22784,
#  48,
#  45072,
#  20,
#  33914,
#  47487,
#  33921,
#  40298,
#  36098,
#  23841,
#  40550,
#  90,
#  14860,
#  209,
#  27,
#  41,
#  30407,
#  23841,
#  33963,
#  46780,
#  11157,
#  40452,
#  62,
#  11157,
#  48334,
#  40592,
#  48950,
#  17744,
#  48,
#  47508,
#  8182,
#  10366,
#  33935,
#  6698,
#  46752,
#  36014,
#  62,
#  36014,
#  33949,
#  17653,
#  40452,
#  48929,
#  76,
#  30435,
#  55,
#  17653,
#  41,
#  47508,
#  45940,
#  48,
#  48341,
#  17583,
#  40592,
#  40424,
#  42573,
#  13166,
#  27,
#  47487,
#  48334,
#  29763,
#  46731,
#  8987,
#  8917,
#  216,
#  40452,
#  34,
#  36070,
#  17982,
#  23316,
#  49650,
#  251,
#  41,
#  33935,
#  188,
#  13957,
#  188,
#  30400,
#  8987,
#  45947,
#  48,
#  251,
#  10366,
#  8700,
#  40550,
#  36084,
#  40550,
#  42573,
#  76,
#  33935,
#  62,
#  14454,
#  76,
#  46745,
#  118,
#  36098,
#  8917,
#  46766,
#  48341,
#  46773,
#  46745,
#  46738,
#  18570,
#  118,
#  22763,
#  40550,
#  7608,
#  6698,
#  30428,
#  23750,
#  8700,
#  46752,
#  8917,
#  40550,
#  47487,
#  8700,
#  8700,
#  46731,
#  40606,
#  272,
#  251,
#  33956,
#  40578,
#  23869,
#  23841,
#  46745,
#  8987,
#  33914,
#  48,
#  40578,
#  44904,
#  46773,
#  237,
#  30400,
#  27,
#  33914,
#  10618,
#  30400,
#  40606,
#  33928,
#  30428,
#  23841,
#  36084,
#  9876,
#  251,
#  23750,
#  36098,
#  15497,
#  33921,
#  55,
#  46773,
#  55,
#  7573,
#  33942,
#  33928]

# %%
y_pred_01=ensemble_pred
win_prob=ensemble_prob

# %%
# adding y_pred_01 to test_data
new_test_data['win_pred_team_id'] = y_pred_01

# %%
# adding winning probability to test_data
new_test_data['win_pred_score'] = win_prob

# %%
new_test_data.head(10)
# Out:
#    team1_id  team2_id  venue  city  match_dt  lighting  series_name  season  \
# 0     28594        90     11    13        69         0           49       1
# 1     36084     36098     59    70       146         2           11       1
# 2     30428     48334      8    58        97         2           18       1
# 3     36098     36112     23    38       107         2           11       3
# 4     30414     48341     46    71       113         2           18       1
# 5     30407     30435     57    20        17         2           18       3
# 6     36014     30414     45    23       142         2           18       3
# 7      9701      6698     81    81        58         2           50       1
# 8      7727      7573     82    76       208         1           50       3
# 9     30428     36014     67    42         8         1           18       3
#
#    ground_id  team_count_50runs_last15  team_winp_last5  \
# 0       3226                  0.000000         0.019608
# 1      13915                  0.615385         0.344262
# 2       2764                  0.842105         0.753086
# 3      11892                  0.285714         1.487805
# 4      18752                  2.375000         0.310330
# 5       7118                  0.400000         0.672131
# 6       2050                  0.681818         0.344262
# 7       1042                  3.200000         0.603960
# 8       8301                  2.428571         2.904762
# 9      13880                  1.727273        21.000000
#
#    team1only_avg_runs_last15  team1_winp_team2_last15  ground_avg_runs_last15  \
# 0                   0.000000                     0.00                0.000000
# 1                 151.285714                    66.67              153.500000
# 2                 171.066667                   100.00              179.625000
# 3                 166.000000                    75.00              155.500000
# 4                 169.933333                     0.00              164.125000
# 5                 177.066667                    50.00              184.500000
# 6                 183.466667                    25.00              156.350000
# 7                 163.066667                     0.00              177.321429
# 8                 167.000000                   100.00              151.600000
# 9                 171.066667                    66.67              186.500000
#
#    batsmens_averages_ratios  batsmens_strike_rates_ratios  \
# 0                  0.580853                      0.443698
# 1                  1.089279                      1.091648
# 2                  1.080138                      0.955992
# 3                  0.871249                      0.848296
# 4                  1.107382                      1.166437
# 5                  0.941093                      0.995272
# 6                  0.921257                      1.034135
# 7                  0.937888                      1.114808
# 8                  1.301483                      1.165019
# 9                  1.161314                      1.008119
#
#    bowlers_strike_rates_ratios  bowlers_economy_ratios  bowlers_extras_ratios  \
# 0                     0.962702                0.439479               1.313131
# 1                     0.840087                0.961859               0.787592
# 2                     0.771592                0.993761               0.900654
# 3                     0.845522                0.870841               0.731058
# 4                     0.963643                1.001825               0.946688
# 5                     1.001928                0.934268               0.736990
# 6                     0.921563                0.955612               0.797946
# 7                     0.635880                0.685779               1.635887
# 8                     1.046915                0.940972               1.415819
# 9                     0.596095                1.011756               1.146592
#
#    team1_winp_team2_last10  team1_average_score  team2_average_score  \
# 0                     0.00           141.000000           144.500000
# 1                    66.67           156.300000           148.125000
# 2                     0.00           168.142857           159.400000
# 3                     0.00           148.125000           166.800000
# 4                     0.00           165.307692           167.916667
# 5                     0.00           172.400000           169.307692
# 6                    25.00           170.000000           165.307692
# 7                     0.00           159.500000           165.857143
# 8                   100.00           158.000000           159.312500
# 9                     0.00           168.142857           170.000000
#
#    win_percentage_team1_last_15  win_percentage_team2_last_15  match_id  \
# 0                      0.000000                           0.0   9250275
# 1                     60.000000                          40.0   9262189
# 2                      0.000000                           0.0   9128776
# 3                      0.000000                           0.0   9586919
# 4                      0.000000                           0.0   9128538
# 5                      0.000000                           0.0   9516653
# 6                     33.333333                          60.0   9516534
# 7                      0.000000                           0.0   9085474
# 8                     80.000000                          40.0   9433752
# 9                      0.000000                           0.0   9516359
#
#    toss_winner  toss_decision  win_pred_team_id  win_pred_score
# 0          104              1             28594        0.007758
# 1           40              1             36084        0.134157
# 2           82              0             30428        0.141598
# 3           92              1             36112        0.027756
# 4           31              1             48341        0.272571
# 5           57              1             30407        0.310271
# 6           12              1             30414        0.184515
# 7           19              1              6698        0.099865
# 8           30              1              7727        0.043026
# 9           89              1             30428        0.267419

# %% [markdown]
# ## Filling submission 1 csv

# %%
submission1=pd.read_csv('sample_template/submission_template_file1.csv')

# %%
submission1.head(2)
# Out:
#    match id dataset_type  win_pred_team_id  win_pred_score  train_algorithm  \
# 0   9250275           r1               NaN             NaN              NaN
# 1   9262189           r1               NaN             NaN              NaN
#
#    is_ensemble  train_hps_trees  train_hps_depth  train_hps_lr  \
# 0          NaN              NaN              NaN           NaN
# 1          NaN              NaN              NaN           NaN
#
#    indep_feat_id1  indep_feat_id2  indep_feat_id3  indep_feat_id4  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
#
#    indep_feat_id5  indep_feat_id6  indep_feat_id7  indep_feat_id8  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
#
#    indep_feat_id9  indep_feat_id10
# 0             NaN              NaN
# 1             NaN              NaN

# %%
# filling submisssion 1 win_pred_team_id, win_pred_score with new_test_data win_pred_team_id, win_pred_score according to match id

# also filling train_algorithm as xgboost , is_ensemble=no , train_hps_tree=150, train_hps_depth=6, train_hps_lr=0.1 for all rows

for i in range(len(submission1)):
    match_id = submission1['match id'][i]
    if match_id not in new_test_data['match_id'].values:
        continue
    new_test_data_row = new_test_data[new_test_data['match_id'] == match_id]
    submission1.at[i, 'win_pred_team_id'] = new_test_data_row['win_pred_team_id'].values[0]
    submission1.at[i, 'win_pred_score'] = new_test_data_row['win_pred_score'].values[0]
    submission1.at[i, 'train_algorithm'] = 'xgboost-catboost-ensemble'
    submission1.at[i, 'is_ensemble'] = 'yes'
    submission1.at[i, 'train_hps_trees'] = 150
    submission1.at[i, 'train_hps_depth'] = 6
    submission1.at[i, 'train_hps_lr'] = 0.1
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\71239456.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'xgboost-catboost-ensemble' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission1.at[i, 'train_algorithm'] = 'xgboost-catboost-ensemble'
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\71239456.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'yes' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission1.at[i, 'is_ensemble'] = 'yes'

# %%
submission1.head(10)
# Out:
#    match id dataset_type  win_pred_team_id  win_pred_score  \
# 0   9250275           r1           28594.0        0.007758
# 1   9262189           r1           36084.0        0.134157
# 2   9128776           r1           30428.0        0.141598
# 3   9586919           r1           36112.0        0.027756
# 4   9128538           r1           48341.0        0.272571
# 5   9516653           r1           30407.0        0.310271
# 6   9516534           r1           30414.0        0.184515
# 7   9085474           r1            6698.0        0.099865
# 8   9433752           r1            7727.0        0.043026
# 9   9516359           r1           30428.0        0.267419
#
#              train_algorithm is_ensemble  train_hps_trees  train_hps_depth  \
# 0  xgboost-catboost-ensemble         yes            150.0              6.0
# 1  xgboost-catboost-ensemble         yes            150.0              6.0
# 2  xgboost-catboost-ensemble         yes            150.0              6.0
# 3  xgboost-catboost-ensemble         yes            150.0              6.0
# 4  xgboost-catboost-ensemble         yes            150.0              6.0
# 5  xgboost-catboost-ensemble         yes            150.0              6.0
# 6  xgboost-catboost-ensemble         yes            150.0              6.0
# 7  xgboost-catboost-ensemble         yes            150.0              6.0
# 8  xgboost-catboost-ensemble         yes            150.0              6.0
# 9  xgboost-catboost-ensemble         yes            150.0              6.0
#
#    train_hps_lr  indep_feat_id1  indep_feat_id2  indep_feat_id3  \
# 0           0.1             NaN             NaN             NaN
# 1           0.1             NaN             NaN             NaN
# 2           0.1             NaN             NaN             NaN
# 3           0.1             NaN             NaN             NaN
# 4           0.1             NaN             NaN             NaN
# 5           0.1             NaN             NaN             NaN
# 6           0.1             NaN             NaN             NaN
# 7           0.1             NaN             NaN             NaN
# 8           0.1             NaN             NaN             NaN
# 9           0.1             NaN             NaN             NaN
#
#    indep_feat_id4  indep_feat_id5  indep_feat_id6  indep_feat_id7  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
# 5             NaN             NaN             NaN             NaN
# 6             NaN             NaN             NaN             NaN
# 7             NaN             NaN             NaN             NaN
# 8             NaN             NaN             NaN             NaN
# 9             NaN             NaN             NaN             NaN
#
#    indep_feat_id8  indep_feat_id9  indep_feat_id10
# 0             NaN             NaN              NaN
# 1             NaN             NaN              NaN
# 2             NaN             NaN              NaN
# 3             NaN             NaN              NaN
# 4             NaN             NaN              NaN
# 5             NaN             NaN              NaN
# 6             NaN             NaN              NaN
# 7             NaN             NaN              NaN
# 8             NaN             NaN              NaN
# 9             NaN             NaN              NaN

# %% [markdown]
# ## Now genearting for train data

# %%
new_train_data.head(2)
# Out:
#    team1_id  team2_id  winner_id  venue  city  match_dt  lighting  \
# 0     11283     12634      12634     44    55       212         1
# 1        20        41         20     53    13        20         1
#
#    series_name  season  ground_id  team_count_50runs_last15  team_winp_last5  \
# 0           58       2       7398                  1.666667         0.672131
# 1           22       0       1406                  1.285714         1.952381
#
#    team1only_avg_runs_last15  team1_winp_team2_last15  ground_avg_runs_last15  \
# 0                      139.0                    100.0              157.178571
# 1                      156.0                     50.0              103.500000
#
#    batsmens_averages_ratios  batsmens_strike_rates_ratios  \
# 0                  2.028272                      2.611098
# 1                  1.024794                      0.966568
#
#    bowlers_strike_rates_ratios  bowlers_economy_ratios  bowlers_extras_ratios  \
# 0                     4.638805                2.351068               1.710894
# 1                     0.797703                0.807080               0.374242
#
#    team1_winp_team2_last10  team1_average_score  team2_average_score  \
# 0                    100.0           137.666667           116.500000
# 1                     50.0           157.730769           157.791667
#
#    win_percentage_team1_last_15  win_percentage_team2_last_15  match_id  \
# 0                          60.0                     63.636364   9331181
# 1                          60.0                     40.000000   8797060
#
#    toss_winner  toss_decision
# 0           44              1
# 1          138              1

# %%
train_team1_ids = new_train_data['team1_id']
train_team2_ids = new_train_data['team2_id']

# %%
# scalling and x train and y train
X_train = new_train_data.drop(['winner_id'], axis=1)
y_train = new_train_data['winner_id']

# scalling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
accuracy_score(cat_model.predict(X_train), y_train)
# Out:
# 0.9156118143459916

# %%
cat_preds = cat_model.predict_proba(X_train)

# %%
cat_preds.shape
# Out:
# (948, 139)

# %%
X_train.shape
# Out:
# (948, 27)

# %%
# Create DMatrix for training and testing
xgb_train = xgb.DMatrix(X_train, enable_categorical=True)
# xgb_test = xgb.DMatrix(X_test, enable_categorical=True)  # No label for xgb_test

# %%
xgb_preds = xgb_model.predict(xgb_train)

# %%
xgb_preds.shape
# Out:
# (948, 139)

# %%
# Compare probabilities and assign the team with higher probability
y_pred_01 = []
win_prob=[]
for i in range(len(xgb_preds)):
    team1_id = train_team1_ids[i]
    team2_id = train_team2_ids[i]
    
    team1_index = class_to_index.get(team1_id, -1)
    team2_index = class_to_index.get(team2_id, -1)
    
    if team1_index == -1 and team2_index == -1:
        y_pred_01.append(team1_id)
        win_prob.append(0)
        
        continue
        # raise ValueError(f"Team ID {team1_id} or {team2_id} not found in class_to_index mapping.")
    
    team1_prob = xgb_preds[i][team1_index]  # Probability for team1_id
    team2_prob = xgb_preds[i][team2_index]  # Probability for team2_id
    
    if team1_prob > team2_prob:
        y_pred_01.append(team1_id)  # team1_id
        win_prob.append(team1_prob)
    else:
        y_pred_01.append(team2_id)  # team2_id
        win_prob.append(team2_prob)

# %%
# printing winning team along with their winning probability
for i in range(len(y_pred_01)):
    print(f"Match {i+1}: {y_pred_01[i]} with probability {win_prob[i]}")
# Out:
# Match 1: 12634 with probability 0.8592671751976013
# Match 2: 20 with probability 0.8937444686889648
# Match 3: 10576 with probability 0.8723538517951965
# Match 4: 36084 with probability 0.8804664611816406
# Match 5: 48341 with probability 0.948393702507019
# Match 6: 40424 with probability 0.9025112986564636
# Match 7: 55 with probability 0.988191545009613
# Match 8: 47501 with probability 0.9442260265350342
# Match 9: 12634 with probability 0.8743334412574768
# Match 10: 55 with probability 0.8995677828788757
# Match 11: 30414 with probability 0.9270097613334656
# Match 12: 30435 with probability 0.9063557386398315
# Match 13: 36014 with probability 0.8538640737533569
# Match 14: 8301 with probability 0.899867594242096
# Match 15: 10618 with probability 0.9181980490684509
# Match 16: 30393 with probability 0.9548448324203491
# Match 17: 33956 with probability 0.9375231266021729
# Match 18: 188 with probability 0.9336394667625427
# Match 19: 7727 with probability 0.9784219264984131
# Match 20: 251 with probability 0.9742836952209473
# Match 21: 40298 with probability 0.9604091048240662
# Match 22: 18570 with probability 0.9025688767433167
# Match 23: 47508 with probability 0.9607784152030945
# Match 24: 20 with probability 0.9393572807312012
# Match 25: 8917 with probability 0.9268980622291565
# Match 26: 10366 with probability 0.9405864477157593
# Match 27: 17653 with probability 0.9259012341499329
# Match 28: 47480 with probability 0.9476150870323181
# Match 29: 42573 with probability 0.9056038856506348
# Match 30: 12046 with probability 0.8341559767723083
# Match 31: 55 with probability 0.9587023258209229
# Match 32: 44904 with probability 0.9609659314155579
# Match 33: 33914 with probability 0.9103325605392456
# Match 34: 46752 with probability 0.9410845041275024
# Match 35: 48 with probability 0.9315193891525269
# Match 36: 17744 with probability 0.8702405691146851
# Match 919: 8182 with probability 0.8807260990142822
# Match 920: 34 with probability 0.954468309879303
# Match 921: 9876 with probability 0.9462201595306396
# Match 922: 15301 with probability 0.20935112237930298
# Match 923: 17744 with probability 0.8297749161720276
# Match 924: 34 with probability 0.9136021137237549
# Match 925: 23750 with probability 0.9765567779541016
# Match 926: 8056 with probability 0.9029828906059265
# Match 927: 30393 with probability 0.9451836347579956
# Match 928: 7727 with probability 0.9248772263526917
# Match 929: 40564 with probability 0.8927299976348877
# Match 930: 11220 with probability 0.9077377915382385
# Match 931: 1490 with probability 0.795183539390564
# Match 932: 30414 with probability 0.9293698072433472
# Match 933: 216 with probability 0.9047551155090332
# Match 934: 40592 with probability 0.819929301738739
# Match 935: 40578 with probability 0.8943576812744141
# Match 936: 6838 with probability 0.9027421474456787
# Match 937: 9967 with probability 0.833057165145874
# Match 938: 17583 with probability 0.8534666895866394
# Match 939: 30400 with probability 0.9338436126708984
# Match 940: 55 with probability 0.9673209190368652
# Match 941: 272 with probability 0.8015041351318359
# Match 942: 45072 with probability 0.8961420059204102
# Match 943: 33935 with probability 0.9670206308364868
# Match 944: 30407 with probability 0.9219818115234375
# Match 945: 9701 with probability 0.9297886490821838
# Match 946: 23869 with probability 0.8946353197097778
# Match 947: 36014 with probability 0.879094660282135
# Match 948: 7608 with probability 0.9533177614212036

# %%
# cat_preds = cat_model.predict_proba(X_train)
# Compare probabilities and assign the team with higher probability 
cat_y_pred_01 = []
cat_win_prob = []
for i in range(len(cat_preds)):
    team1_id = train_team1_ids[i]
    team2_id = train_team2_ids[i]

    team1_index = class_to_index.get(team1_id, -1)
    team2_index = class_to_index.get(team2_id, -1)

    if team1_index == -1 and team2_index == -1:
        cat_y_pred_01.append(team1_id)
        cat_win_prob.append(0)

        continue
        # raise ValueError(f"Team ID {team1_id} or {team2_id} not found in class_to_index mapping.")

    team1_prob = cat_preds[i][team1_index]  # Probability for team1_id
    team2_prob = cat_preds[i][team2_index]  # Probability for team2_id

    if team1_prob > team2_prob:
        cat_y_pred_01.append(team1_id)  # team1_id
        cat_win_prob.append(team1_prob)
    else:
        cat_y_pred_01.append(team2_id)  # team2_id
        cat_win_prob.append(team2_prob)

# %%
# printing winning team along with their winning probability
for i in range(len(cat_y_pred_01)):
    print(f"Match {i+1}: {cat_y_pred_01[i]} with probability {cat_win_prob[i]}")
# Out:
# Match 1: 12634 with probability 0.6908398996337619
# Match 2: 20 with probability 0.0476049371912421
# Match 3: 10576 with probability 0.5755352971693442
# Match 4: 36084 with probability 0.6199478184181156
# Match 5: 48341 with probability 0.8255967049867855
# Match 6: 40424 with probability 0.7541206763530969
# Match 7: 55 with probability 0.2618201860625222
# Match 8: 47501 with probability 0.9126797179509518
# Match 9: 12634 with probability 0.6348532718935135
# Match 10: 55 with probability 0.37687424201695374
# Match 11: 30414 with probability 0.29147749862837724
# Match 12: 30435 with probability 0.7953689333240211
# Match 13: 36014 with probability 0.8183062551143228
# Match 14: 8301 with probability 0.4152372694749473
# Match 895: 47529 with probability 0.5818361480611921
# Match 896: 46745 with probability 0.8477853495734962
# Match 897: 7608 with probability 0.4413725896014386
# Match 898: 46731 with probability 0.3448095351081205
# Match 899: 22763 with probability 0.33841488049271257
# Match 900: 8700 with probability 0.8506115173790082
# Match 901: 48929 with probability 0.5620425917360538
# Match 902: 209 with probability 0.8676863214989259
# Match 903: 33942 with probability 0.7764789363909452
# Match 904: 9701 with probability 0.695706637668437
# Match 905: 202 with probability 0.7911327049339325
# Match 906: 30400 with probability 0.7753011951271868
# Match 907: 48341 with probability 0.7908306135989794
# Match 908: 48929 with probability 0.7883916556749131
# Match 909: 36084 with probability 0.8835289465094276
# Match 910: 47508 with probability 0.9717106436211975
# Match 911: 17982 with probability 0.9560241926326497
# Match 912: 10618 with probability 0.6106883160643923
# Match 913: 7608 with probability 0.3718829901956774
# Match 914: 55 with probability 0.1564609290112847
# Match 915: 76 with probability 0.29759746274672627
# Match 916: 46773 with probability 0.8128135934300826
# Match 917: 33935 with probability 0.5627423874730199
# Match 918: 202 with probability 0.9440556498371491
# Match 919: 8182 with probability 0.7250436558560374
# Match 920: 34 with probability 0.2437405188659898
# Match 921: 9876 with probability 0.8020711659926484
# Match 922: 15301 with probability 0.9873011420499003
# Match 923: 17744 with probability 0.761313544788773
# Match 924: 34 with probability 0.4190873506948676
# Match 925: 23750 with probability 0.9531183493304507
# Match 926: 8056 with probability 0.9554294210030693
# Match 927: 30393 with probability 0.8442615531043769
# Match 928: 7727 with probability 0.29935936798402735
# Match 929: 40564 with probability 0.8111842629789348
# Match 930: 11220 with probability 0.8551672056888615
# Match 931: 1490 with probability 0.9780710010367617
# Match 932: 30414 with probability 0.38962470088369755
# Match 933: 216 with probability 0.7573635340981609
# Match 934: 40592 with probability 0.6481922794156454
# Match 935: 40578 with probability 0.979515579278187
# Match 936: 6838 with probability 0.5972169980127802
# Match 937: 9967 with probability 0.5794740367968612
# Match 938: 17583 with probability 0.6787341969845366
# Match 939: 30400 with probability 0.4658926392325561
# Match 940: 55 with probability 0.25617784381537706
# Match 941: 272 with probability 0.9591084914885014
# Match 942: 45072 with probability 0.78271162683104
# Match 943: 33935 with probability 0.704119562611924
# Match 944: 30407 with probability 0.47760681537636396
# Match 945: 9701 with probability 0.4049155965137626
# Match 946: 23869 with probability 0.7156480081565356
# Match 947: 36014 with probability 0.5686373272848994
# Match 948: 7608 with probability 0.8262538227678426

# %%
len(win_prob)
# Out:
# 948

# %%
ensemble_pred = []
ensemble_prob = []

for i in range(len(y_pred_01)):
    if(y_pred_01[i] == cat_y_pred_01[i]):
        ensemble_pred.append(y_pred_01[i])
        ensemble_prob.append(0.5 * (cat_win_prob[i] + win_prob[i]))

    elif (cat_win_prob[i] > win_prob[i]):
        ensemble_pred.append(cat_y_pred_01[i])
        ensemble_prob.append(cat_win_prob[i])

    else:
        ensemble_pred.append(y_pred_01[i])
        ensemble_prob.append(win_prob[i])

# %%
new_train_data['win_pred_team_id'] = ensemble_pred

# %%
# adding winning probability to test_data
new_train_data['win_pred_score'] = ensemble_prob

# %%
new_train_data.head(5)
# Out:
#    team1_id  team2_id  winner_id  venue  city  match_dt  lighting  \
# 0     11283     12634      12634     44    55       212         1
# 1        20        41         20     53    13        20         1
# 2     10576      8987      10576    111    83       370         1
# 3     36084     36070      36084     10   105       434         0
# 4     30407     48341      48341     75    25       331         2
#
#    series_name  season  ground_id  team_count_50runs_last15  team_winp_last5  \
# 0           58       2       7398                  1.666667         0.672131
# 1           22       0       1406                  1.285714         1.952381
# 2           79       3        251                  0.857143         0.672131
# 3           18       3      14300                  2.166667         1.975610
# 4           35       3       7118                  0.818182         1.327869
#
#    team1only_avg_runs_last15  team1_winp_team2_last15  ground_avg_runs_last15  \
# 0                 139.000000                    100.0              157.178571
# 1                 156.000000                     50.0              103.500000
# 2                 173.266667                      0.0              154.333333
# 3                 164.266667                     50.0              144.250000
# 4                 164.666667                      0.0              189.000000
#
#    batsmens_averages_ratios  batsmens_strike_rates_ratios  \
# 0                  2.028272                      2.611098
# 1                  1.024794                      0.966568
# 2                  1.000138                      0.909712
# 3                  1.116102                      1.052218
# 4                  1.035394                      1.240634
#
#    bowlers_strike_rates_ratios  bowlers_economy_ratios  bowlers_extras_ratios  \
# 0                     4.638805                2.351068               1.710894
# 1                     0.797703                0.807080               0.374242
# 2                     0.850190                0.717828               1.024538
# 3                     0.813452                0.878287               0.700727
# 4                     1.084338                1.168234               1.480742
#
#    team1_winp_team2_last10  team1_average_score  team2_average_score  \
# 0                    100.0           137.666667           116.500000
# 1                     50.0           157.730769           157.791667
# 2                      0.0           166.944444           149.588235
# 3                     50.0           156.300000           177.076923
# 4                      0.0           172.400000           167.916667
#
#    win_percentage_team1_last_15  win_percentage_team2_last_15  match_id  \
# 0                     60.000000                     63.636364   9331181
# 1                     60.000000                     40.000000   8797060
# 2                     40.000000                     46.666667   9433269
# 3                     60.000000                     66.666667   9587073
# 4                     53.333333                     69.230769   9516457
#
#    toss_winner  toss_decision  win_pred_team_id  win_pred_score
# 0           44              1             12634        0.775054
# 1          138              1                20        0.470675
# 2           81              1             10576        0.723945
# 3           34              0             36084        0.750207
# 4           40              1             48341        0.886995

# %%
cat_model.get_all_params()
# Out:
# {'nan_mode': 'Min',
#  'eval_metric': 'MultiClass',
#  'iterations': 1000,
#  'sampling_frequency': 'PerTree',
#  'leaf_estimation_method': 'Newton',
#  'random_score_type': 'NormalWithModelSizeDecrease',
#  'grow_policy': 'SymmetricTree',
#  'penalties_coefficient': 1,
#  'boosting_type': 'Plain',
#  'model_shrink_mode': 'Constant',
#  'feature_border_type': 'GreedyLogSum',
#  'bayesian_matrix_reg': 0.10000000149011612,
#  'eval_fraction': 0,
#  'force_unit_auto_pair_weights': False,
#  'l2_leaf_reg': 3,
#  'random_strength': 1,
#  'rsm': 1,
#  'boost_from_average': False,
#  'model_size_reg': 0.5,
#  'pool_metainfo_options': {'tags': {}},
#  'use_best_model': False,
#  'class_names': [20,
#   27,
#   34,
#   41,
#   48,
#   55,
#   62,
#   69,
#   76,
#   90,
#   118,
#   146,
#   188,
#   195,
#   202,
#   209,
#   216,
#   223,
#   237,
#   251,
#   272,
#   279,
#   293,
#   300,
#   769,
#   825,
#   958,
#   1490,
#   6698,
#   6838,
#   7258,
#   7573,
#   7608,
#   7727,
#   8056,
#   8182,
#   8301,
#   8700,
#   8917,
#   8987,
#   9701,
#   9876,
#   9967,
#   10366,
#   10576,
#   10618,
#   11157,
#   11220,
#   11283,
#   11591,
#   12046,
#   12473,
#   12634,
#   12669,
#   12718,
#   13131,
#   13166,
#   13957,
#   14454,
#   14629,
#   14860,
#   15301,
#   15413,
#   15497,
#   15623,
#   17583,
#   17653,
#   17744,
#   17982,
#   18360,
#   18570,
#   22497,
#   22763,
#   22784,
#   23113,
#   23316,
#   23750,
#   23841,
#   23869,
#   28594,
#   30393,
#   30400,
#   30407,
#   30414,
#   30421,
#   30428,
#   30435,
#   33914,
#   33921,
#   33928,
#   33935,
#   33942,
#   33949,
#   33956,
#   33963,
#   35790,
#   36014,
#   36070,
#   36084,
#   36098,
#   36112,
#   36126,
#   38814,
#   40298,
#   40424,
#   40452,
#   40550,
#   40564,
#   40578,
#   40592,
#   40606,
#   42573,
#   44904,
#   45072,
#   45961,
#   46731,
#   46738,
#   46745,
#   46752,
#   46759,
#   46766,
#   46773,
#   46780,
#   47480,
#   47487,
#   47494,
#   47501,
#   47508,
#   47529,
#   48334,
#   48341,
#   48733,
#   48922,
#   48929,
#   48936,
#   48943,
#   48950,
#   49650,
#   49657],
#  'random_seed': 0,
#  'depth': 6,
#  'posterior_sampling': False,
#  'border_count': 254,
#  'bagging_temperature': 1,
#  'classes_count': 0,
#  'auto_class_weights': 'None',
#  'sparse_features_conflict_fraction': 0,
#  'leaf_estimation_backtracking': 'AnyImprovement',
#  'best_model_min_trees': 1,
#  'model_shrink_rate': 0,
#  'min_data_in_leaf': 1,
#  'loss_function': 'MultiClass',
#  'learning_rate': 0.08495700359344482,
#  'score_function': 'Cosine',
#  'task_type': 'CPU',
#  'leaf_estimation_iterations': 1,
#  'bootstrap_type': 'Bayesian',
#  'max_leaves': 64}

# %%
for i in range(len(submission1)):
    match_id = submission1['match id'][i]
    if match_id not in new_train_data['match_id'].values:
        continue
    new_train_data_row = new_train_data[new_train_data['match_id'] == match_id]
    submission1.at[i, 'win_pred_team_id'] = new_train_data_row['win_pred_team_id'].values[0]
    submission1.at[i, 'win_pred_score'] = new_train_data_row['win_pred_score'].values[0]
    submission1.at[i, 'train_algorithm'] = 'xgboost-catboost-ensemble'
    submission1.at[i, 'is_ensemble'] = 'yes'
    submission1.at[i, 'train_hps_trees'] = 150
    submission1.at[i, 'train_hps_depth'] = 6
    submission1.at[i, 'train_hps_lr'] = 0.1

# %% [markdown]
# ## CSV-2 Generation

# %%
train_data.columns
# Out:
# Index(['team1_id', 'team2_id', 'winner_id', 'venue', 'city', 'match_dt',
#        'lighting', 'series_name', 'season', 'ground_id',
#        'team_count_50runs_last15', 'team_winp_last5',
#        'team1only_avg_runs_last15', 'team1_winp_team2_last15',
#        'ground_avg_runs_last15', 'batsmens_averages_ratios',
#        'batsmens_strike_rates_ratios', 'bowlers_strike_rates_ratios',
#        'bowlers_economy_ratios', 'bowlers_extras_ratios',
#        'team1_winp_team2_last10', 'team1_average_score', 'team2_average_score',
#        'win_percentage_team1_last_15', 'win_percentage_team2_last_15',
#        'match_id', 'toss_winner', 'toss_decision', 'win_pred_team_id',
#        'win_pred_score'],
#       dtype='object')

# %%
cols = train_data.columns[-15:-5]

# %%
cols
# Out:
# Index(['batsmens_averages_ratios', 'batsmens_strike_rates_ratios',
#        'bowlers_strike_rates_ratios', 'bowlers_economy_ratios',
#        'bowlers_extras_ratios', 'team1_winp_team2_last10',
#        'team1_average_score', 'team2_average_score',
#        'win_percentage_team1_last_15', 'win_percentage_team2_last_15'],
#       dtype='object')

# %%
ft_dict = cat_model.get_feature_importance()

# %%
ft_dict
# Out:
# array([ 7.80900644,  6.08932603,  5.41663391,  5.47226815,  1.51087058,
#         3.21027929, 10.8410908 ,  2.54966508,  3.2388673 ,  1.96549767,
#         3.0865692 ,  4.37174384,  0.6776219 ,  3.05949681,  1.4476404 ,
#         1.54685818,  2.96260578,  1.89513903,  1.98141025,  2.16928731,
#         7.89146647,  8.46925044,  2.55744238,  3.33497025,  1.32843192,
#         3.63979761,  1.476763  ])

# %%
ft_dict[-15:-5]
# Out:
# array([0.6776219 , 3.05949681, 1.4476404 , 1.54685818, 2.96260578,
#        1.89513903, 1.98141025, 2.16928731, 7.89146647, 8.46925044])

# %%
sorted_dict = {}
for key in sorted(ft_dict, key=ft_dict.get):
    sorted_dict[key] = ft_dict[key]
sorted_dict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\Amex\pipeline(4).ipynb Cell 95 line 2
#       <a href='vscode-notebook-cell:/e%3A/Amex/pipeline%284%29.ipynb#Y156sZmlsZQ%3D%3D?line=0'>1</a> sorted_dict = {}
# ----> <a href='vscode-notebook-cell:/e%3A/Amex/pipeline%284%29.ipynb#Y156sZmlsZQ%3D%3D?line=1'>2</a> for key in sorted(ft_dict, key=ft_dict.get):
#       <a href='vscode-notebook-cell:/e%3A/Amex/pipeline%284%29.ipynb#Y156sZmlsZQ%3D%3D?line=2'>3</a>     sorted_dict[key] = ft_dict[key]
#       <a href='vscode-notebook-cell:/e%3A/Amex/pipeline%284%29.ipynb#Y156sZmlsZQ%3D%3D?line=3'>4</a> sorted_dict
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get'

# %%
sorted_list = list(sorted_dict.keys())

# %%
feat = pd.read_csv('sample_template/submission_template_file2.csv')

# %%
feat['feat_id'] = np.arange(1, 11)

# %%
feat['feat_name'] = cols

# %%
feat
# Out:
#    feat_id                     feat_name feat_description  \
# 0        1      batsmens_averages_ratios              NaN
# 1        2  batsmens_strike_rates_ratios              NaN
# 2        3   bowlers_strike_rates_ratios              NaN
# 3        4        bowlers_economy_ratios              NaN
# 4        5         bowlers_extras_ratios              NaN
# 5        6       team1_winp_team2_last10              NaN
# 6        7           team1_average_score              NaN
# 7        8           team2_average_score              NaN
# 8        9  win_percentage_team1_last_15              NaN
# 9       10  win_percentage_team2_last_15              NaN
#
#   model_feat_imp_train feat_rank_train
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
# 5                  NaN             NaN
# 6                  NaN             NaN
# 7                  NaN             NaN
# 8                  NaN             NaN
# 9                  NaN             NaN

# %%
for i in range(10):
    feat['model_feat_imp_train'][i] = ft_dict[i]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19632\4059413501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feat['model_feat_imp_train'][i] = ft_dict[i]

# %%
filtered_feats = []
for i in range(10):
    filtered_feats.append(f'f{14+i}')

# %%
filtered_feats
# Out:
# ['f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23']

# %%
for i in range(10):
    feat['feat_rank_train'][i] = sorted_list.index(filtered_feats[i]) + 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\Amex\pipeline(4).ipynb Cell 104 line 2
#       <a href='vscode-notebook-cell:/e%3A/Amex/pipeline%284%29.ipynb#Y201sZmlsZQ%3D%3D?line=0'>1</a> for i in range(10):
# ----> <a href='vscode-notebook-cell:/e%3A/Amex/pipeline%284%29.ipynb#Y201sZmlsZQ%3D%3D?line=1'>2</a>     feat['feat_rank_train'][i] = sorted_list.index(filtered_feats[i]) + 1
#
# ValueError: 'f14' is not in list

# %%
feat.to_csv('sample_template/submission_file2-2.csv')

# %%
submission1.to_csv('sample_template/submission_file1-2.csv', index=False)

# %%
train_check=pd.read_csv('dataset/train_data.csv')

# %%
# checking count of matchings between y_pred_01 and winner_id
count=0
for i in range(len(cat_y_pred_01)):
    if cat_y_pred_01[i] == train_check['winner_id'][i]:
        count+=1
        
print(count)
# print((count/948)*100)
# Out:
# 96.51898734177216
